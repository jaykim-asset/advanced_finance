# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
from dask import dataframe as dd
from dask.diagnostics import ProgressBar
pbar = ProgressBar()
pbar.register()
from multiprocessing import cpu_count
import statsmodels.api as sm
import math
import matplotlib.pyplot as plt
from tqdm import tqdm, tqdm_notebook
import scipy.stats as stats
from IPython.display import display
from IPython.core.debugger import set_trace as bp
import os
from statsmodels.tsa.stattools import adfuller

# %matplotlib inline

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc

from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, BaggingClassifier
from sklearn.model_selection import train_test_split

import pyfolio as pf
from scipy import interp

from random import gauss
import scipy.stats as ss
# Out:
# C:\Users\Jay\lib\site-packages\pyfolio\pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'

# %% [markdown]
# # Chapter 11 - The Dangers of Backtesting

# %%
def testAccuracy_MC(sr_base, sr_case):
    """
    Test the accuracy of CSCV against hold-out
    It generates numTrials random samples and directly computes the _____
    ____ proportion where OOS performance was below the median
    """
    length, numTrials, numMC = 1000, 100, 1000

    # 1) Determine mu, sigma
    mu_base, sigma_base = sr_base / (365.25 * 5 / 7.00), 1 / (365.25 * 5 / 7.00) ** 0.5

    mu_case, sigma_case = sr_case / (365.25 * 5 / 7.00), 1 / (365.25 * 5 / 7.00) ** 0.5

    hist, probOverfit = [], 0

    # 2) Generate trials
    # M Matrix build from gaussian distribution
    for m in range(numMC):
        for i in range(1, numTrials):
            j = np.array([gauss(0, 1) for j in range(length)])
            j *= sigma_base / np.std(j) # re-scale
            j += mu_base - np.mean(j) # re-center
            j = np.reshape(j, (j.shape[0], 1))

            if i == 1:
                pnl = np.copy(j)
            else:
                pnl = np.append(pnl, j, axis=1)
    # 3) Add test case
        j = np.array([gauss(0, 1) for j in range(length)])
        j *= sigma_case / np.std(j) # re-scale
        j += mu_case - np.mean(j)
        j = np.reshape(j, (j.shape[0], 1))
        pnl = np.append(pnl, j, axis=1)

    # 4) Run test
        mu_is = [np.average(pnl[:length//2, i]) for i in range(pnl.shape[1])]
        sigma_is = [np.std(pnl[:length//2, i]) for i in range(pnl.shape[1])]

        mu_oos = [np.average(pnl[length//2:, i]) for i in range(pnl.shape[1])]
        sigma_oos = [np.std(pnl[length//2:,i]) for i in range(pnl.shape[1])]

        sr_is = [mu_is[i]/ sigma_is[i] for i in range(len(mu_is))]
        sr_oos = [mu_oos[i]/sigma_oos[i] for i in range(len(mu_oos))]

        print('# matrix:', m, '# max index:', sr_is.index(max(sr_is)), '# Max_IS_sharpe_ratio:', round(max(sr_is), 4), '# Max_OOS_sharpe_ratio:', round(sr_oos[sr_is.index(max(sr_is))], 4))

        sr_oos_ = sr_oos[sr_is.index(max(sr_is))]

        # out of sample result saved 
        hist.append(sr_oos_)

        # over fitting count 
        if sr_oos_ < np.median(sr_oos):
            probOverfit += 1

    probOverfit /= float(numMC)

    print(probOverfit)
    return

# %%
testAccuracy_MC(1000, 900)
# Out:
# # matrix: 0 # max index: 27 # Max_IS_sharpe_ratio: 66.3233 # Max_OOS_sharpe_ratio: 58.2854
# # matrix: 1 # max index: 20 # Max_IS_sharpe_ratio: 64.7249 # Max_OOS_sharpe_ratio: 59.6277
# # matrix: 2 # max index: 57 # Max_IS_sharpe_ratio: 66.6072 # Max_OOS_sharpe_ratio: 58.0977
# # matrix: 3 # max index: 46 # Max_IS_sharpe_ratio: 66.385 # Max_OOS_sharpe_ratio: 58.2543
# # matrix: 4 # max index: 10 # Max_IS_sharpe_ratio: 64.7693 # Max_OOS_sharpe_ratio: 59.4709
# # matrix: 5 # max index: 80 # Max_IS_sharpe_ratio: 66.0362 # Max_OOS_sharpe_ratio: 58.4929
# # matrix: 6 # max index: 73 # Max_IS_sharpe_ratio: 65.1139 # Max_OOS_sharpe_ratio: 59.1572
# # matrix: 7 # max index: 55 # Max_IS_sharpe_ratio: 66.2876 # Max_OOS_sharpe_ratio: 58.3237
# # matrix: 8 # max index: 27 # Max_IS_sharpe_ratio: 64.6875 # Max_OOS_sharpe_ratio: 59.5364
# # matrix: 9 # max index: 37 # Max_IS_sharpe_ratio: 65.2381 # Max_OOS_sharpe_ratio: 59.0523
# # matrix: 10 # max index: 18 # Max_IS_sharpe_ratio: 66.0282 # Max_OOS_sharpe_ratio: 58.5728
# # matrix: 11 # max index: 9 # Max_IS_sharpe_ratio: 65.6664 # Max_OOS_sharpe_ratio: 58.7617
# # matrix: 12 # max index: 80 # Max_IS_sharpe_ratio: 65.9325 # Max_OOS_sharpe_ratio: 58.6047
# # matrix: 13 # max index: 67 # Max_IS_sharpe_ratio: 65.8164 # Max_OOS_sharpe_ratio: 58.6277
# # matrix: 14 # max index: 57 # Max_IS_sharpe_ratio: 65.9536 # Max_OOS_sharpe_ratio: 58.59
# # matrix: 15 # max index: 49 # Max_IS_sharpe_ratio: 65.8997 # Max_OOS_sharpe_ratio: 58.7914
# # matrix: 16 # max index: 41 # Max_IS_sharpe_ratio: 65.2988 # Max_OOS_sharpe_ratio: 59.0018
# # matrix: 17 # max index: 48 # Max_IS_sharpe_ratio: 66.4022 # Max_OOS_sharpe_ratio: 58.2315
# # matrix: 18 # max index: 35 # Max_IS_sharpe_ratio: 65.4955 # Max_OOS_sharpe_ratio: 58.8578
# # matrix: 19 # max index: 14 # Max_IS_sharpe_ratio: 65.7895 # Max_OOS_sharpe_ratio: 58.6639
# # matrix: 20 # max index: 51 # Max_IS_sharpe_ratio: 65.3157 # Max_OOS_sharpe_ratio: 59.0066
# # matrix: 21 # max index: 52 # Max_IS_sharpe_ratio: 64.8138 # Max_OOS_sharpe_ratio: 59.3677
# # matrix: 22 # max index: 52 # Max_IS_sharpe_ratio: 64.9478 # Max_OOS_sharpe_ratio: 59.2785
# # matrix: 23 # max index: 23 # Max_IS_sharpe_ratio: 65.8106 # Max_OOS_sharpe_ratio: 58.6455
# # matrix: 24 # max index: 52 # Max_IS_sharpe_ratio: 66.2005 # Max_OOS_sharpe_ratio: 58.3601
# # matrix: 25 # max index: 56 # Max_IS_sharpe_ratio: 64.7127 # Max_OOS_sharpe_ratio: 59.5757
# # matrix: 26 # max index: 35 # Max_IS_sharpe_ratio: 66.4542 # Max_OOS_sharpe_ratio: 58.271
# # matrix: 27 # max index: 24 # Max_IS_sharpe_ratio: 65.2357 # Max_OOS_sharpe_ratio: 59.1539
# # matrix: 28 # max index: 37 # Max_IS_sharpe_ratio: 65.7459 # Max_OOS_sharpe_ratio: 58.7106
# # matrix: 29 # max index: 49 # Max_IS_sharpe_ratio: 64.8219 # Max_OOS_sharpe_ratio: 59.3613
# # matrix: 30 # max index: 15 # Max_IS_sharpe_ratio: 66.002 # Max_OOS_sharpe_ratio: 58.4972
# # matrix: 31 # max index: 42 # Max_IS_sharpe_ratio: 65.271 # Max_OOS_sharpe_ratio: 59.1481
# # matrix: 32 # max index: 24 # Max_IS_sharpe_ratio: 64.9615 # Max_OOS_sharpe_ratio: 59.2623
# # matrix: 33 # max index: 87 # Max_IS_sharpe_ratio: 66.6471 # Max_OOS_sharpe_ratio: 58.0634
# # matrix: 34 # max index: 25 # Max_IS_sharpe_ratio: 64.4517 # Max_OOS_sharpe_ratio: 59.6791
# # matrix: 35 # max index: 0 # Max_IS_sharpe_ratio: 65.2834 # Max_OOS_sharpe_ratio: 59.0924
# # matrix: 36 # max index: 50 # Max_IS_sharpe_ratio: 64.5268 # Max_OOS_sharpe_ratio: 59.5921
# # matrix: 37 # max index: 66 # Max_IS_sharpe_ratio: 66.5214 # Max_OOS_sharpe_ratio: 58.3051
# # matrix: 38 # max index: 85 # Max_IS_sharpe_ratio: 64.8522 # Max_OOS_sharpe_ratio: 59.5111
# # matrix: 39 # max index: 51 # Max_IS_sharpe_ratio: 66.0153 # Max_OOS_sharpe_ratio: 58.4979
# # matrix: 40 # max index: 93 # Max_IS_sharpe_ratio: 65.5474 # Max_OOS_sharpe_ratio: 58.9618
# # matrix: 41 # max index: 84 # Max_IS_sharpe_ratio: 65.9857 # Max_OOS_sharpe_ratio: 58.6399
# # matrix: 42 # max index: 17 # Max_IS_sharpe_ratio: 65.545 # Max_OOS_sharpe_ratio: 58.8223
# # matrix: 43 # max index: 59 # Max_IS_sharpe_ratio: 66.4659 # Max_OOS_sharpe_ratio: 58.194
# # matrix: 44 # max index: 65 # Max_IS_sharpe_ratio: 65.3413 # Max_OOS_sharpe_ratio: 58.9983
# # matrix: 45 # max index: 85 # Max_IS_sharpe_ratio: 65.0293 # Max_OOS_sharpe_ratio: 59.245
# # matrix: 46 # max index: 63 # Max_IS_sharpe_ratio: 66.3181 # Max_OOS_sharpe_ratio: 58.3221
# # matrix: 47 # max index: 92 # Max_IS_sharpe_ratio: 65.4588 # Max_OOS_sharpe_ratio: 58.8982
# # matrix: 48 # max index: 92 # Max_IS_sharpe_ratio: 65.3057 # Max_OOS_sharpe_ratio: 59.0243
# # matrix: 49 # max index: 18 # Max_IS_sharpe_ratio: 66.3984 # Max_OOS_sharpe_ratio: 58.4364
# # matrix: 50 # max index: 43 # Max_IS_sharpe_ratio: 65.2143 # Max_OOS_sharpe_ratio: 59.064
# # matrix: 51 # max index: 21 # Max_IS_sharpe_ratio: 64.789 # Max_OOS_sharpe_ratio: 59.4811
# # matrix: 52 # max index: 38 # Max_IS_sharpe_ratio: 65.2937 # Max_OOS_sharpe_ratio: 59.0753
# # matrix: 53 # max index: 4 # Max_IS_sharpe_ratio: 65.0722 # Max_OOS_sharpe_ratio: 59.1833
# # matrix: 54 # max index: 61 # Max_IS_sharpe_ratio: 65.8685 # Max_OOS_sharpe_ratio: 58.7188
# # matrix: 55 # max index: 72 # Max_IS_sharpe_ratio: 66.5287 # Max_OOS_sharpe_ratio: 58.2962
# # matrix: 56 # max index: 20 # Max_IS_sharpe_ratio: 65.5209 # Max_OOS_sharpe_ratio: 58.8869
# # matrix: 57 # max index: 49 # Max_IS_sharpe_ratio: 65.4377 # Max_OOS_sharpe_ratio: 58.9342
# # matrix: 58 # max index: 45 # Max_IS_sharpe_ratio: 64.8382 # Max_OOS_sharpe_ratio: 59.3502
# # matrix: 59 # max index: 3 # Max_IS_sharpe_ratio: 65.3097 # Max_OOS_sharpe_ratio: 59.0776
# # matrix: 60 # max index: 51 # Max_IS_sharpe_ratio: 65.251 # Max_OOS_sharpe_ratio: 59.0405
# # matrix: 61 # max index: 26 # Max_IS_sharpe_ratio: 65.4066 # Max_OOS_sharpe_ratio: 59.0198
# # matrix: 62 # max index: 31 # Max_IS_sharpe_ratio: 64.8632 # Max_OOS_sharpe_ratio: 59.4262
# # matrix: 63 # max index: 8 # Max_IS_sharpe_ratio: 64.7572 # Max_OOS_sharpe_ratio: 59.4543
# # matrix: 64 # max index: 43 # Max_IS_sharpe_ratio: 67.309 # Max_OOS_sharpe_ratio: 57.7722
# # matrix: 65 # max index: 83 # Max_IS_sharpe_ratio: 65.6961 # Max_OOS_sharpe_ratio: 58.8089
# # matrix: 66 # max index: 95 # Max_IS_sharpe_ratio: 66.7516 # Max_OOS_sharpe_ratio: 58.0519
# # matrix: 67 # max index: 93 # Max_IS_sharpe_ratio: 66.4935 # Max_OOS_sharpe_ratio: 58.1647
# # matrix: 68 # max index: 58 # Max_IS_sharpe_ratio: 67.2137 # Max_OOS_sharpe_ratio: 57.7383
# # matrix: 69 # max index: 69 # Max_IS_sharpe_ratio: 66.2243 # Max_OOS_sharpe_ratio: 58.3648
# # matrix: 70 # max index: 9 # Max_IS_sharpe_ratio: 66.4571 # Max_OOS_sharpe_ratio: 58.2007
# # matrix: 71 # max index: 76 # Max_IS_sharpe_ratio: 65.3549 # Max_OOS_sharpe_ratio: 58.9844
# # matrix: 72 # max index: 9 # Max_IS_sharpe_ratio: 64.7688 # Max_OOS_sharpe_ratio: 59.4025
# # matrix: 73 # max index: 4 # Max_IS_sharpe_ratio: 66.7106 # Max_OOS_sharpe_ratio: 58.0176
# # matrix: 74 # max index: 89 # Max_IS_sharpe_ratio: 66.0124 # Max_OOS_sharpe_ratio: 58.5112
# # matrix: 75 # max index: 82 # Max_IS_sharpe_ratio: 66.1034 # Max_OOS_sharpe_ratio: 58.5359
# # matrix: 76 # max index: 96 # Max_IS_sharpe_ratio: 65.2829 # Max_OOS_sharpe_ratio: 59.0167
# # matrix: 77 # max index: 4 # Max_IS_sharpe_ratio: 65.403 # Max_OOS_sharpe_ratio: 58.9979
# # matrix: 78 # max index: 83 # Max_IS_sharpe_ratio: 65.05 # Max_OOS_sharpe_ratio: 59.2864
# # matrix: 79 # max index: 41 # Max_IS_sharpe_ratio: 65.2589 # Max_OOS_sharpe_ratio: 59.0309
# # matrix: 80 # max index: 14 # Max_IS_sharpe_ratio: 64.8336 # Max_OOS_sharpe_ratio: 59.4151
# # matrix: 81 # max index: 93 # Max_IS_sharpe_ratio: 66.9959 # Max_OOS_sharpe_ratio: 57.9072
# # matrix: 82 # max index: 17 # Max_IS_sharpe_ratio: 65.4082 # Max_OOS_sharpe_ratio: 58.9318
# # matrix: 83 # max index: 49 # Max_IS_sharpe_ratio: 65.3558 # Max_OOS_sharpe_ratio: 59.0427
# # matrix: 84 # max index: 90 # Max_IS_sharpe_ratio: 65.7241 # Max_OOS_sharpe_ratio: 58.7118
# # matrix: 85 # max index: 0 # Max_IS_sharpe_ratio: 66.377 # Max_OOS_sharpe_ratio: 58.5385
# # matrix: 86 # max index: 98 # Max_IS_sharpe_ratio: 66.0194 # Max_OOS_sharpe_ratio: 58.5969
# # matrix: 87 # max index: 69 # Max_IS_sharpe_ratio: 65.889 # Max_OOS_sharpe_ratio: 58.6523
# # matrix: 88 # max index: 6 # Max_IS_sharpe_ratio: 64.6897 # Max_OOS_sharpe_ratio: 59.4698
# # matrix: 89 # max index: 6 # Max_IS_sharpe_ratio: 64.9801 # Max_OOS_sharpe_ratio: 59.3234
# # matrix: 90 # max index: 51 # Max_IS_sharpe_ratio: 65.2111 # Max_OOS_sharpe_ratio: 59.0967
# # matrix: 91 # max index: 93 # Max_IS_sharpe_ratio: 65.79 # Max_OOS_sharpe_ratio: 58.7025
# # matrix: 92 # max index: 45 # Max_IS_sharpe_ratio: 66.4635 # Max_OOS_sharpe_ratio: 58.1826
# # matrix: 93 # max index: 43 # Max_IS_sharpe_ratio: 65.2939 # Max_OOS_sharpe_ratio: 59.0086
# # matrix: 94 # max index: 31 # Max_IS_sharpe_ratio: 65.2278 # Max_OOS_sharpe_ratio: 59.0972
# # matrix: 95 # max index: 83 # Max_IS_sharpe_ratio: 64.9059 # Max_OOS_sharpe_ratio: 59.3045
# # matrix: 96 # max index: 38 # Max_IS_sharpe_ratio: 64.661 # Max_OOS_sharpe_ratio: 59.4879
# # matrix: 97 # max index: 16 # Max_IS_sharpe_ratio: 64.8148 # Max_OOS_sharpe_ratio: 59.3693
# # matrix: 98 # max index: 83 # Max_IS_sharpe_ratio: 65.056 # Max_OOS_sharpe_ratio: 59.2439
# # matrix: 99 # max index: 16 # Max_IS_sharpe_ratio: 65.8579 # Max_OOS_sharpe_ratio: 58.6012
# # matrix: 100 # max index: 77 # Max_IS_sharpe_ratio: 67.6668 # Max_OOS_sharpe_ratio: 57.4702
# # matrix: 101 # max index: 61 # Max_IS_sharpe_ratio: 65.0944 # Max_OOS_sharpe_ratio: 59.1548
# # matrix: 102 # max index: 89 # Max_IS_sharpe_ratio: 66.0497 # Max_OOS_sharpe_ratio: 58.5146
# # matrix: 103 # max index: 45 # Max_IS_sharpe_ratio: 64.6964 # Max_OOS_sharpe_ratio: 59.4983
# # matrix: 104 # max index: 24 # Max_IS_sharpe_ratio: 66.233 # Max_OOS_sharpe_ratio: 58.3724
# # matrix: 105 # max index: 36 # Max_IS_sharpe_ratio: 65.156 # Max_OOS_sharpe_ratio: 59.1463
# # matrix: 106 # max index: 92 # Max_IS_sharpe_ratio: 66.696 # Max_OOS_sharpe_ratio: 58.2409
# # matrix: 107 # max index: 25 # Max_IS_sharpe_ratio: 65.7647 # Max_OOS_sharpe_ratio: 58.6759
# # matrix: 108 # max index: 37 # Max_IS_sharpe_ratio: 66.222 # Max_OOS_sharpe_ratio: 58.6142
# # matrix: 109 # max index: 18 # Max_IS_sharpe_ratio: 66.03 # Max_OOS_sharpe_ratio: 58.6101
# # matrix: 110 # max index: 90 # Max_IS_sharpe_ratio: 65.9819 # Max_OOS_sharpe_ratio: 58.512
# # matrix: 111 # max index: 13 # Max_IS_sharpe_ratio: 66.1239 # Max_OOS_sharpe_ratio: 58.4325
# # matrix: 112 # max index: 32 # Max_IS_sharpe_ratio: 65.1865 # Max_OOS_sharpe_ratio: 59.1537
# # matrix: 113 # max index: 57 # Max_IS_sharpe_ratio: 66.546 # Max_OOS_sharpe_ratio: 58.2247
# # matrix: 114 # max index: 61 # Max_IS_sharpe_ratio: 65.2186 # Max_OOS_sharpe_ratio: 59.1082
# # matrix: 115 # max index: 10 # Max_IS_sharpe_ratio: 66.6841 # Max_OOS_sharpe_ratio: 58.0465
# # matrix: 116 # max index: 63 # Max_IS_sharpe_ratio: 66.1053 # Max_OOS_sharpe_ratio: 58.7798
# # matrix: 117 # max index: 56 # Max_IS_sharpe_ratio: 65.163 # Max_OOS_sharpe_ratio: 59.1066
# # matrix: 118 # max index: 16 # Max_IS_sharpe_ratio: 69.6939 # Max_OOS_sharpe_ratio: 56.2713
# # matrix: 119 # max index: 95 # Max_IS_sharpe_ratio: 65.8222 # Max_OOS_sharpe_ratio: 58.6828
# # matrix: 120 # max index: 8 # Max_IS_sharpe_ratio: 67.6083 # Max_OOS_sharpe_ratio: 57.5547
# # matrix: 121 # max index: 67 # Max_IS_sharpe_ratio: 65.1289 # Max_OOS_sharpe_ratio: 59.1392
# # matrix: 122 # max index: 41 # Max_IS_sharpe_ratio: 65.9744 # Max_OOS_sharpe_ratio: 58.5851
# # matrix: 123 # max index: 43 # Max_IS_sharpe_ratio: 65.4266 # Max_OOS_sharpe_ratio: 59.0185
# # matrix: 124 # max index: 43 # Max_IS_sharpe_ratio: 65.3127 # Max_OOS_sharpe_ratio: 59.0416
# # matrix: 125 # max index: 74 # Max_IS_sharpe_ratio: 66.14 # Max_OOS_sharpe_ratio: 58.4021
# # matrix: 126 # max index: 97 # Max_IS_sharpe_ratio: 65.3854 # Max_OOS_sharpe_ratio: 59.1557
# # matrix: 127 # max index: 59 # Max_IS_sharpe_ratio: 65.9663 # Max_OOS_sharpe_ratio: 58.5625
# # matrix: 128 # max index: 1 # Max_IS_sharpe_ratio: 64.9108 # Max_OOS_sharpe_ratio: 59.7717
# # matrix: 129 # max index: 90 # Max_IS_sharpe_ratio: 65.571 # Max_OOS_sharpe_ratio: 58.8828
# # matrix: 130 # max index: 38 # Max_IS_sharpe_ratio: 65.5563 # Max_OOS_sharpe_ratio: 58.815
# # matrix: 131 # max index: 92 # Max_IS_sharpe_ratio: 65.7911 # Max_OOS_sharpe_ratio: 58.6481
# # matrix: 132 # max index: 53 # Max_IS_sharpe_ratio: 65.9407 # Max_OOS_sharpe_ratio: 58.5611
# # matrix: 133 # max index: 57 # Max_IS_sharpe_ratio: 67.0194 # Max_OOS_sharpe_ratio: 58.0399
# # matrix: 134 # max index: 53 # Max_IS_sharpe_ratio: 64.842 # Max_OOS_sharpe_ratio: 59.5188
# # matrix: 135 # max index: 13 # Max_IS_sharpe_ratio: 65.4527 # Max_OOS_sharpe_ratio: 58.8909
# # matrix: 136 # max index: 57 # Max_IS_sharpe_ratio: 65.2597 # Max_OOS_sharpe_ratio: 59.2401
# # matrix: 137 # max index: 54 # Max_IS_sharpe_ratio: 67.1448 # Max_OOS_sharpe_ratio: 57.8318
# # matrix: 138 # max index: 61 # Max_IS_sharpe_ratio: 64.9468 # Max_OOS_sharpe_ratio: 59.267
# # matrix: 139 # max index: 76 # Max_IS_sharpe_ratio: 66.0736 # Max_OOS_sharpe_ratio: 58.551
# # matrix: 140 # max index: 34 # Max_IS_sharpe_ratio: 66.5572 # Max_OOS_sharpe_ratio: 58.1752
# # matrix: 141 # max index: 86 # Max_IS_sharpe_ratio: 65.2889 # Max_OOS_sharpe_ratio: 59.1186
# # matrix: 142 # max index: 81 # Max_IS_sharpe_ratio: 65.4995 # Max_OOS_sharpe_ratio: 58.8559
# # matrix: 143 # max index: 11 # Max_IS_sharpe_ratio: 65.2197 # Max_OOS_sharpe_ratio: 59.0634
# # matrix: 144 # max index: 2 # Max_IS_sharpe_ratio: 65.7877 # Max_OOS_sharpe_ratio: 58.651
# # matrix: 145 # max index: 21 # Max_IS_sharpe_ratio: 67.1698 # Max_OOS_sharpe_ratio: 57.721
# # matrix: 146 # max index: 60 # Max_IS_sharpe_ratio: 65.8843 # Max_OOS_sharpe_ratio: 58.6204
# # matrix: 147 # max index: 94 # Max_IS_sharpe_ratio: 65.2662 # Max_OOS_sharpe_ratio: 59.0283
# # matrix: 148 # max index: 50 # Max_IS_sharpe_ratio: 64.938 # Max_OOS_sharpe_ratio: 59.324
# # matrix: 149 # max index: 87 # Max_IS_sharpe_ratio: 65.0803 # Max_OOS_sharpe_ratio: 59.2013
# # matrix: 150 # max index: 98 # Max_IS_sharpe_ratio: 65.5565 # Max_OOS_sharpe_ratio: 58.9101
# # matrix: 151 # max index: 35 # Max_IS_sharpe_ratio: 65.1134 # Max_OOS_sharpe_ratio: 59.1972
# # matrix: 152 # max index: 19 # Max_IS_sharpe_ratio: 66.1969 # Max_OOS_sharpe_ratio: 58.3797
# # matrix: 153 # max index: 68 # Max_IS_sharpe_ratio: 65.5682 # Max_OOS_sharpe_ratio: 58.8066
# # matrix: 154 # max index: 80 # Max_IS_sharpe_ratio: 67.5932 # Max_OOS_sharpe_ratio: 57.4568
# # matrix: 155 # max index: 33 # Max_IS_sharpe_ratio: 65.1614 # Max_OOS_sharpe_ratio: 59.1186
# # matrix: 156 # max index: 53 # Max_IS_sharpe_ratio: 65.9121 # Max_OOS_sharpe_ratio: 58.5609
# # matrix: 157 # max index: 83 # Max_IS_sharpe_ratio: 66.0893 # Max_OOS_sharpe_ratio: 58.4471
# # matrix: 158 # max index: 1 # Max_IS_sharpe_ratio: 66.6628 # Max_OOS_sharpe_ratio: 58.0585
# # matrix: 159 # max index: 7 # Max_IS_sharpe_ratio: 65.2447 # Max_OOS_sharpe_ratio: 59.1694
# # matrix: 160 # max index: 95 # Max_IS_sharpe_ratio: 65.2848 # Max_OOS_sharpe_ratio: 59.1534
# # matrix: 161 # max index: 15 # Max_IS_sharpe_ratio: 64.654 # Max_OOS_sharpe_ratio: 59.492
# # matrix: 162 # max index: 54 # Max_IS_sharpe_ratio: 66.192 # Max_OOS_sharpe_ratio: 58.4754
# # matrix: 163 # max index: 45 # Max_IS_sharpe_ratio: 65.8012 # Max_OOS_sharpe_ratio: 58.6463
# # matrix: 164 # max index: 76 # Max_IS_sharpe_ratio: 65.3634 # Max_OOS_sharpe_ratio: 59.0292
# # matrix: 165 # max index: 46 # Max_IS_sharpe_ratio: 65.6474 # Max_OOS_sharpe_ratio: 58.7525
# # matrix: 166 # max index: 48 # Max_IS_sharpe_ratio: 66.1594 # Max_OOS_sharpe_ratio: 58.4398
# # matrix: 167 # max index: 61 # Max_IS_sharpe_ratio: 66.6283 # Max_OOS_sharpe_ratio: 58.4181
# # matrix: 168 # max index: 72 # Max_IS_sharpe_ratio: 64.5914 # Max_OOS_sharpe_ratio: 59.5587
# # matrix: 169 # max index: 62 # Max_IS_sharpe_ratio: 65.2555 # Max_OOS_sharpe_ratio: 59.0348
# # matrix: 170 # max index: 10 # Max_IS_sharpe_ratio: 65.6754 # Max_OOS_sharpe_ratio: 58.8269
# # matrix: 171 # max index: 24 # Max_IS_sharpe_ratio: 66.1736 # Max_OOS_sharpe_ratio: 58.4875
# # matrix: 172 # max index: 54 # Max_IS_sharpe_ratio: 65.6407 # Max_OOS_sharpe_ratio: 58.7886
# # matrix: 173 # max index: 60 # Max_IS_sharpe_ratio: 65.9075 # Max_OOS_sharpe_ratio: 58.5894
# # matrix: 174 # max index: 52 # Max_IS_sharpe_ratio: 65.5429 # Max_OOS_sharpe_ratio: 58.8648
# # matrix: 175 # max index: 48 # Max_IS_sharpe_ratio: 65.177 # Max_OOS_sharpe_ratio: 59.2016
# # matrix: 176 # max index: 56 # Max_IS_sharpe_ratio: 64.8677 # Max_OOS_sharpe_ratio: 59.3255
# # matrix: 177 # max index: 39 # Max_IS_sharpe_ratio: 64.6413 # Max_OOS_sharpe_ratio: 59.5366
# # matrix: 178 # max index: 27 # Max_IS_sharpe_ratio: 65.0854 # Max_OOS_sharpe_ratio: 59.1623
# # matrix: 179 # max index: 5 # Max_IS_sharpe_ratio: 65.5911 # Max_OOS_sharpe_ratio: 58.7895
# # matrix: 180 # max index: 64 # Max_IS_sharpe_ratio: 65.0619 # Max_OOS_sharpe_ratio: 59.1834
# # matrix: 181 # max index: 14 # Max_IS_sharpe_ratio: 65.7722 # Max_OOS_sharpe_ratio: 58.8497
# # matrix: 182 # max index: 70 # Max_IS_sharpe_ratio: 65.36 # Max_OOS_sharpe_ratio: 59.0952
# # matrix: 183 # max index: 45 # Max_IS_sharpe_ratio: 65.9007 # Max_OOS_sharpe_ratio: 58.6421
# # matrix: 184 # max index: 85 # Max_IS_sharpe_ratio: 65.5599 # Max_OOS_sharpe_ratio: 58.8177
# # matrix: 185 # max index: 10 # Max_IS_sharpe_ratio: 64.6523 # Max_OOS_sharpe_ratio: 59.4958
# # matrix: 186 # max index: 13 # Max_IS_sharpe_ratio: 65.8937 # Max_OOS_sharpe_ratio: 58.6631
# # matrix: 187 # max index: 46 # Max_IS_sharpe_ratio: 64.9032 # Max_OOS_sharpe_ratio: 59.4051
# # matrix: 188 # max index: 81 # Max_IS_sharpe_ratio: 65.0687 # Max_OOS_sharpe_ratio: 59.179
# # matrix: 189 # max index: 15 # Max_IS_sharpe_ratio: 65.113 # Max_OOS_sharpe_ratio: 59.2254
# # matrix: 190 # max index: 7 # Max_IS_sharpe_ratio: 66.3563 # Max_OOS_sharpe_ratio: 58.4337
# # matrix: 191 # max index: 90 # Max_IS_sharpe_ratio: 66.4608 # Max_OOS_sharpe_ratio: 58.1846
# # matrix: 192 # max index: 63 # Max_IS_sharpe_ratio: 65.1974 # Max_OOS_sharpe_ratio: 59.1246
# # matrix: 193 # max index: 92 # Max_IS_sharpe_ratio: 66.1989 # Max_OOS_sharpe_ratio: 58.3783
# # matrix: 194 # max index: 49 # Max_IS_sharpe_ratio: 65.63 # Max_OOS_sharpe_ratio: 58.78
# # matrix: 195 # max index: 0 # Max_IS_sharpe_ratio: 65.0308 # Max_OOS_sharpe_ratio: 59.2037
# # matrix: 196 # max index: 30 # Max_IS_sharpe_ratio: 64.5783 # Max_OOS_sharpe_ratio: 59.6221
# # matrix: 197 # max index: 48 # Max_IS_sharpe_ratio: 65.8309 # Max_OOS_sharpe_ratio: 58.6424
# # matrix: 198 # max index: 47 # Max_IS_sharpe_ratio: 65.7216 # Max_OOS_sharpe_ratio: 58.7808
# # matrix: 199 # max index: 45 # Max_IS_sharpe_ratio: 65.3587 # Max_OOS_sharpe_ratio: 58.9608
# # matrix: 200 # max index: 67 # Max_IS_sharpe_ratio: 65.6314 # Max_OOS_sharpe_ratio: 58.7624
# # matrix: 201 # max index: 59 # Max_IS_sharpe_ratio: 66.2806 # Max_OOS_sharpe_ratio: 58.3224
# # matrix: 202 # max index: 4 # Max_IS_sharpe_ratio: 66.8571 # Max_OOS_sharpe_ratio: 57.9665
# # matrix: 203 # max index: 71 # Max_IS_sharpe_ratio: 65.3916 # Max_OOS_sharpe_ratio: 58.9611
# # matrix: 204 # max index: 72 # Max_IS_sharpe_ratio: 65.1244 # Max_OOS_sharpe_ratio: 59.1797
# # matrix: 205 # max index: 78 # Max_IS_sharpe_ratio: 67.1799 # Max_OOS_sharpe_ratio: 57.817
# # matrix: 206 # max index: 22 # Max_IS_sharpe_ratio: 65.4145 # Max_OOS_sharpe_ratio: 58.9729
# # matrix: 207 # max index: 89 # Max_IS_sharpe_ratio: 66.0848 # Max_OOS_sharpe_ratio: 58.4543
# # matrix: 208 # max index: 6 # Max_IS_sharpe_ratio: 66.0422 # Max_OOS_sharpe_ratio: 58.4816
# # matrix: 209 # max index: 47 # Max_IS_sharpe_ratio: 66.0223 # Max_OOS_sharpe_ratio: 58.6196
# # matrix: 210 # max index: 62 # Max_IS_sharpe_ratio: 65.8723 # Max_OOS_sharpe_ratio: 58.596
# # matrix: 211 # max index: 71 # Max_IS_sharpe_ratio: 66.0024 # Max_OOS_sharpe_ratio: 58.5296
# # matrix: 212 # max index: 28 # Max_IS_sharpe_ratio: 64.9547 # Max_OOS_sharpe_ratio: 59.4563
# # matrix: 213 # max index: 77 # Max_IS_sharpe_ratio: 64.925 # Max_OOS_sharpe_ratio: 59.5458
# # matrix: 214 # max index: 32 # Max_IS_sharpe_ratio: 65.7637 # Max_OOS_sharpe_ratio: 58.6704
# # matrix: 215 # max index: 59 # Max_IS_sharpe_ratio: 65.1168 # Max_OOS_sharpe_ratio: 59.3496
# # matrix: 216 # max index: 74 # Max_IS_sharpe_ratio: 65.2186 # Max_OOS_sharpe_ratio: 59.0655
# # matrix: 217 # max index: 95 # Max_IS_sharpe_ratio: 64.7357 # Max_OOS_sharpe_ratio: 59.5707
# # matrix: 218 # max index: 56 # Max_IS_sharpe_ratio: 66.9208 # Max_OOS_sharpe_ratio: 57.8816
# # matrix: 219 # max index: 71 # Max_IS_sharpe_ratio: 65.0652 # Max_OOS_sharpe_ratio: 59.3022
# # matrix: 220 # max index: 13 # Max_IS_sharpe_ratio: 65.6705 # Max_OOS_sharpe_ratio: 58.7615
# # matrix: 221 # max index: 45 # Max_IS_sharpe_ratio: 65.7619 # Max_OOS_sharpe_ratio: 58.666
# # matrix: 222 # max index: 25 # Max_IS_sharpe_ratio: 66.0579 # Max_OOS_sharpe_ratio: 58.4626
# # matrix: 223 # max index: 51 # Max_IS_sharpe_ratio: 65.5064 # Max_OOS_sharpe_ratio: 58.8497
# # matrix: 224 # max index: 67 # Max_IS_sharpe_ratio: 65.6674 # Max_OOS_sharpe_ratio: 58.7554
# # matrix: 225 # max index: 23 # Max_IS_sharpe_ratio: 65.5394 # Max_OOS_sharpe_ratio: 58.8546
# # matrix: 226 # max index: 20 # Max_IS_sharpe_ratio: 66.0904 # Max_OOS_sharpe_ratio: 58.4359
# # matrix: 227 # max index: 9 # Max_IS_sharpe_ratio: 65.9292 # Max_OOS_sharpe_ratio: 58.66
# # matrix: 228 # max index: 83 # Max_IS_sharpe_ratio: 65.0312 # Max_OOS_sharpe_ratio: 59.2174
# # matrix: 229 # max index: 81 # Max_IS_sharpe_ratio: 65.9952 # Max_OOS_sharpe_ratio: 58.5109
# # matrix: 230 # max index: 4 # Max_IS_sharpe_ratio: 67.306 # Max_OOS_sharpe_ratio: 57.6691
# # matrix: 231 # max index: 19 # Max_IS_sharpe_ratio: 64.8084 # Max_OOS_sharpe_ratio: 59.3813
# # matrix: 232 # max index: 90 # Max_IS_sharpe_ratio: 65.2608 # Max_OOS_sharpe_ratio: 59.0303
# # matrix: 233 # max index: 15 # Max_IS_sharpe_ratio: 67.3937 # Max_OOS_sharpe_ratio: 57.5876
# # matrix: 234 # max index: 38 # Max_IS_sharpe_ratio: 66.0621 # Max_OOS_sharpe_ratio: 58.4627
# # matrix: 235 # max index: 82 # Max_IS_sharpe_ratio: 65.5717 # Max_OOS_sharpe_ratio: 58.808
# # matrix: 236 # max index: 16 # Max_IS_sharpe_ratio: 65.4222 # Max_OOS_sharpe_ratio: 58.9107
# # matrix: 237 # max index: 39 # Max_IS_sharpe_ratio: 65.757 # Max_OOS_sharpe_ratio: 58.8289
# # matrix: 238 # max index: 3 # Max_IS_sharpe_ratio: 65.533 # Max_OOS_sharpe_ratio: 58.912
# # matrix: 239 # max index: 89 # Max_IS_sharpe_ratio: 67.0364 # Max_OOS_sharpe_ratio: 57.8847
# # matrix: 240 # max index: 77 # Max_IS_sharpe_ratio: 65.892 # Max_OOS_sharpe_ratio: 58.575
# # matrix: 241 # max index: 19 # Max_IS_sharpe_ratio: 65.4607 # Max_OOS_sharpe_ratio: 58.9619
# # matrix: 242 # max index: 73 # Max_IS_sharpe_ratio: 64.9925 # Max_OOS_sharpe_ratio: 59.2376
# # matrix: 243 # max index: 80 # Max_IS_sharpe_ratio: 65.1456 # Max_OOS_sharpe_ratio: 59.1355
# # matrix: 244 # max index: 23 # Max_IS_sharpe_ratio: 65.9468 # Max_OOS_sharpe_ratio: 58.5594
# # matrix: 245 # max index: 75 # Max_IS_sharpe_ratio: 65.5291 # Max_OOS_sharpe_ratio: 58.8684
# # matrix: 246 # max index: 48 # Max_IS_sharpe_ratio: 65.4918 # Max_OOS_sharpe_ratio: 59.0161
# # matrix: 247 # max index: 95 # Max_IS_sharpe_ratio: 65.7824 # Max_OOS_sharpe_ratio: 58.6515
# # matrix: 248 # max index: 22 # Max_IS_sharpe_ratio: 66.5458 # Max_OOS_sharpe_ratio: 58.1322
# # matrix: 249 # max index: 22 # Max_IS_sharpe_ratio: 66.1869 # Max_OOS_sharpe_ratio: 58.3977
# # matrix: 250 # max index: 72 # Max_IS_sharpe_ratio: 66.9784 # Max_OOS_sharpe_ratio: 57.8671
# # matrix: 251 # max index: 54 # Max_IS_sharpe_ratio: 66.4525 # Max_OOS_sharpe_ratio: 58.1913
# # matrix: 252 # max index: 26 # Max_IS_sharpe_ratio: 66.4725 # Max_OOS_sharpe_ratio: 58.2652
# # matrix: 253 # max index: 37 # Max_IS_sharpe_ratio: 66.9899 # Max_OOS_sharpe_ratio: 58.0883
# # matrix: 254 # max index: 14 # Max_IS_sharpe_ratio: 65.1587 # Max_OOS_sharpe_ratio: 59.2005
# # matrix: 255 # max index: 30 # Max_IS_sharpe_ratio: 65.3833 # Max_OOS_sharpe_ratio: 59.3824
# # matrix: 256 # max index: 97 # Max_IS_sharpe_ratio: 65.8043 # Max_OOS_sharpe_ratio: 58.8547
# # matrix: 257 # max index: 41 # Max_IS_sharpe_ratio: 67.3318 # Max_OOS_sharpe_ratio: 57.6219
# # matrix: 258 # max index: 18 # Max_IS_sharpe_ratio: 65.9131 # Max_OOS_sharpe_ratio: 58.5596
# # matrix: 259 # max index: 50 # Max_IS_sharpe_ratio: 66.4872 # Max_OOS_sharpe_ratio: 58.1749
# # matrix: 260 # max index: 76 # Max_IS_sharpe_ratio: 65.7936 # Max_OOS_sharpe_ratio: 58.7115
# # matrix: 261 # max index: 10 # Max_IS_sharpe_ratio: 65.9394 # Max_OOS_sharpe_ratio: 58.9464
# # matrix: 262 # max index: 66 # Max_IS_sharpe_ratio: 65.7212 # Max_OOS_sharpe_ratio: 58.7074
# # matrix: 263 # max index: 81 # Max_IS_sharpe_ratio: 65.2511 # Max_OOS_sharpe_ratio: 59.0393
# # matrix: 264 # max index: 62 # Max_IS_sharpe_ratio: 66.1831 # Max_OOS_sharpe_ratio: 58.3734
# # matrix: 265 # max index: 22 # Max_IS_sharpe_ratio: 66.3435 # Max_OOS_sharpe_ratio: 58.263
# # matrix: 266 # max index: 23 # Max_IS_sharpe_ratio: 65.5426 # Max_OOS_sharpe_ratio: 58.8367
# # matrix: 267 # max index: 92 # Max_IS_sharpe_ratio: 66.1168 # Max_OOS_sharpe_ratio: 58.4568
# # matrix: 268 # max index: 86 # Max_IS_sharpe_ratio: 65.3318 # Max_OOS_sharpe_ratio: 58.9839
# # matrix: 269 # max index: 87 # Max_IS_sharpe_ratio: 64.277 # Max_OOS_sharpe_ratio: 59.9081
# # matrix: 270 # max index: 5 # Max_IS_sharpe_ratio: 66.1234 # Max_OOS_sharpe_ratio: 58.4288
# # matrix: 271 # max index: 73 # Max_IS_sharpe_ratio: 65.2514 # Max_OOS_sharpe_ratio: 59.1265
# # matrix: 272 # max index: 78 # Max_IS_sharpe_ratio: 65.0727 # Max_OOS_sharpe_ratio: 59.17
# # matrix: 273 # max index: 1 # Max_IS_sharpe_ratio: 65.0756 # Max_OOS_sharpe_ratio: 59.1737
# # matrix: 274 # max index: 28 # Max_IS_sharpe_ratio: 65.2339 # Max_OOS_sharpe_ratio: 59.1129
# # matrix: 275 # max index: 73 # Max_IS_sharpe_ratio: 65.3811 # Max_OOS_sharpe_ratio: 58.9411
# # matrix: 276 # max index: 2 # Max_IS_sharpe_ratio: 65.7497 # Max_OOS_sharpe_ratio: 58.687
# # matrix: 277 # max index: 69 # Max_IS_sharpe_ratio: 66.6584 # Max_OOS_sharpe_ratio: 58.066
# # matrix: 278 # max index: 74 # Max_IS_sharpe_ratio: 65.7444 # Max_OOS_sharpe_ratio: 58.6868
# # matrix: 279 # max index: 32 # Max_IS_sharpe_ratio: 66.0216 # Max_OOS_sharpe_ratio: 58.524
# # matrix: 280 # max index: 79 # Max_IS_sharpe_ratio: 65.4307 # Max_OOS_sharpe_ratio: 58.9743
# # matrix: 281 # max index: 92 # Max_IS_sharpe_ratio: 65.3835 # Max_OOS_sharpe_ratio: 58.943
# # matrix: 282 # max index: 95 # Max_IS_sharpe_ratio: 66.5365 # Max_OOS_sharpe_ratio: 58.1356
# # matrix: 283 # max index: 86 # Max_IS_sharpe_ratio: 65.3348 # Max_OOS_sharpe_ratio: 58.9801
# # matrix: 284 # max index: 91 # Max_IS_sharpe_ratio: 65.8397 # Max_OOS_sharpe_ratio: 58.6141
# # matrix: 285 # max index: 20 # Max_IS_sharpe_ratio: 65.5095 # Max_OOS_sharpe_ratio: 58.8967
# # matrix: 286 # max index: 0 # Max_IS_sharpe_ratio: 65.066 # Max_OOS_sharpe_ratio: 59.1802
# # matrix: 287 # max index: 42 # Max_IS_sharpe_ratio: 65.9244 # Max_OOS_sharpe_ratio: 58.6503
# # matrix: 288 # max index: 92 # Max_IS_sharpe_ratio: 65.057 # Max_OOS_sharpe_ratio: 59.2571
# # matrix: 289 # max index: 18 # Max_IS_sharpe_ratio: 65.2028 # Max_OOS_sharpe_ratio: 59.3584
# # matrix: 290 # max index: 15 # Max_IS_sharpe_ratio: 66.6888 # Max_OOS_sharpe_ratio: 58.06
# # matrix: 291 # max index: 68 # Max_IS_sharpe_ratio: 66.458 # Max_OOS_sharpe_ratio: 58.1919
# # matrix: 292 # max index: 79 # Max_IS_sharpe_ratio: 67.19 # Max_OOS_sharpe_ratio: 57.7082
# # matrix: 293 # max index: 36 # Max_IS_sharpe_ratio: 65.8613 # Max_OOS_sharpe_ratio: 58.8636
# # matrix: 294 # max index: 63 # Max_IS_sharpe_ratio: 65.9607 # Max_OOS_sharpe_ratio: 58.5489
# # matrix: 295 # max index: 85 # Max_IS_sharpe_ratio: 65.1447 # Max_OOS_sharpe_ratio: 59.1294
# # matrix: 296 # max index: 46 # Max_IS_sharpe_ratio: 66.1408 # Max_OOS_sharpe_ratio: 58.5106
# # matrix: 297 # max index: 24 # Max_IS_sharpe_ratio: 65.0711 # Max_OOS_sharpe_ratio: 59.3364
# # matrix: 298 # max index: 87 # Max_IS_sharpe_ratio: 65.8703 # Max_OOS_sharpe_ratio: 58.7493
# # matrix: 299 # max index: 17 # Max_IS_sharpe_ratio: 65.332 # Max_OOS_sharpe_ratio: 59.0287
# # matrix: 300 # max index: 33 # Max_IS_sharpe_ratio: 65.185 # Max_OOS_sharpe_ratio: 59.1004
# # matrix: 301 # max index: 84 # Max_IS_sharpe_ratio: 65.3659 # Max_OOS_sharpe_ratio: 59.075
# # matrix: 302 # max index: 0 # Max_IS_sharpe_ratio: 64.7153 # Max_OOS_sharpe_ratio: 59.4908
# # matrix: 303 # max index: 29 # Max_IS_sharpe_ratio: 65.8393 # Max_OOS_sharpe_ratio: 58.6668
# # matrix: 304 # max index: 93 # Max_IS_sharpe_ratio: 65.6454 # Max_OOS_sharpe_ratio: 58.7492
# # matrix: 305 # max index: 38 # Max_IS_sharpe_ratio: 65.3396 # Max_OOS_sharpe_ratio: 58.9816
# # matrix: 306 # max index: 17 # Max_IS_sharpe_ratio: 68.4396 # Max_OOS_sharpe_ratio: 57.1001
# # matrix: 307 # max index: 69 # Max_IS_sharpe_ratio: 65.6837 # Max_OOS_sharpe_ratio: 58.7279
# # matrix: 308 # max index: 55 # Max_IS_sharpe_ratio: 64.3617 # Max_OOS_sharpe_ratio: 59.7416
# # matrix: 309 # max index: 95 # Max_IS_sharpe_ratio: 65.4589 # Max_OOS_sharpe_ratio: 58.885
# # matrix: 310 # max index: 12 # Max_IS_sharpe_ratio: 66.2531 # Max_OOS_sharpe_ratio: 58.3275
# # matrix: 311 # max index: 21 # Max_IS_sharpe_ratio: 65.3858 # Max_OOS_sharpe_ratio: 58.9379
# # matrix: 312 # max index: 86 # Max_IS_sharpe_ratio: 66.3004 # Max_OOS_sharpe_ratio: 58.3748
# # matrix: 313 # max index: 27 # Max_IS_sharpe_ratio: 65.3982 # Max_OOS_sharpe_ratio: 58.9463
# # matrix: 314 # max index: 10 # Max_IS_sharpe_ratio: 67.4996 # Max_OOS_sharpe_ratio: 57.5233
# # matrix: 315 # max index: 70 # Max_IS_sharpe_ratio: 64.0663 # Max_OOS_sharpe_ratio: 59.9754
# # matrix: 316 # max index: 63 # Max_IS_sharpe_ratio: 65.1657 # Max_OOS_sharpe_ratio: 59.2071
# # matrix: 317 # max index: 61 # Max_IS_sharpe_ratio: 65.2719 # Max_OOS_sharpe_ratio: 59.0252
# # matrix: 318 # max index: 75 # Max_IS_sharpe_ratio: 65.3736 # Max_OOS_sharpe_ratio: 59.1226
# # matrix: 319 # max index: 1 # Max_IS_sharpe_ratio: 65.8205 # Max_OOS_sharpe_ratio: 58.6569
# # matrix: 320 # max index: 52 # Max_IS_sharpe_ratio: 66.1651 # Max_OOS_sharpe_ratio: 58.4184
# # matrix: 321 # max index: 5 # Max_IS_sharpe_ratio: 65.4771 # Max_OOS_sharpe_ratio: 58.871
# # matrix: 322 # max index: 96 # Max_IS_sharpe_ratio: 65.1945 # Max_OOS_sharpe_ratio: 59.0849
# # matrix: 323 # max index: 62 # Max_IS_sharpe_ratio: 65.2484 # Max_OOS_sharpe_ratio: 59.0455
# # matrix: 324 # max index: 88 # Max_IS_sharpe_ratio: 65.0526 # Max_OOS_sharpe_ratio: 59.1997
# # matrix: 325 # max index: 4 # Max_IS_sharpe_ratio: 65.1921 # Max_OOS_sharpe_ratio: 59.1587
# # matrix: 326 # max index: 10 # Max_IS_sharpe_ratio: 66.0252 # Max_OOS_sharpe_ratio: 58.4845
# # matrix: 327 # max index: 31 # Max_IS_sharpe_ratio: 65.3997 # Max_OOS_sharpe_ratio: 58.9309
# # matrix: 328 # max index: 20 # Max_IS_sharpe_ratio: 66.0713 # Max_OOS_sharpe_ratio: 58.4755
# # matrix: 329 # max index: 27 # Max_IS_sharpe_ratio: 65.0023 # Max_OOS_sharpe_ratio: 59.2985
# # matrix: 330 # max index: 10 # Max_IS_sharpe_ratio: 65.7606 # Max_OOS_sharpe_ratio: 58.8417
# # matrix: 331 # max index: 76 # Max_IS_sharpe_ratio: 65.6548 # Max_OOS_sharpe_ratio: 58.8174
# # matrix: 332 # max index: 40 # Max_IS_sharpe_ratio: 66.1955 # Max_OOS_sharpe_ratio: 58.4118
# # matrix: 333 # max index: 86 # Max_IS_sharpe_ratio: 64.9727 # Max_OOS_sharpe_ratio: 59.3579
# # matrix: 334 # max index: 97 # Max_IS_sharpe_ratio: 65.0444 # Max_OOS_sharpe_ratio: 59.3098
# # matrix: 335 # max index: 59 # Max_IS_sharpe_ratio: 66.2865 # Max_OOS_sharpe_ratio: 58.3735
# # matrix: 336 # max index: 98 # Max_IS_sharpe_ratio: 65.3824 # Max_OOS_sharpe_ratio: 59.3637
# # matrix: 337 # max index: 22 # Max_IS_sharpe_ratio: 65.6791 # Max_OOS_sharpe_ratio: 58.7709
# # matrix: 338 # max index: 47 # Max_IS_sharpe_ratio: 64.9116 # Max_OOS_sharpe_ratio: 59.3114
# # matrix: 339 # max index: 28 # Max_IS_sharpe_ratio: 66.2649 # Max_OOS_sharpe_ratio: 58.3388
# # matrix: 340 # max index: 6 # Max_IS_sharpe_ratio: 65.1405 # Max_OOS_sharpe_ratio: 59.1189
# # matrix: 341 # max index: 59 # Max_IS_sharpe_ratio: 65.7324 # Max_OOS_sharpe_ratio: 58.6907
# # matrix: 342 # max index: 39 # Max_IS_sharpe_ratio: 65.1456 # Max_OOS_sharpe_ratio: 59.1618
# # matrix: 343 # max index: 21 # Max_IS_sharpe_ratio: 64.7562 # Max_OOS_sharpe_ratio: 59.4718
# # matrix: 344 # max index: 74 # Max_IS_sharpe_ratio: 65.631 # Max_OOS_sharpe_ratio: 58.7638
# # matrix: 345 # max index: 22 # Max_IS_sharpe_ratio: 64.5436 # Max_OOS_sharpe_ratio: 59.5976
# # matrix: 346 # max index: 42 # Max_IS_sharpe_ratio: 66.2603 # Max_OOS_sharpe_ratio: 58.3284
# # matrix: 347 # max index: 76 # Max_IS_sharpe_ratio: 65.4152 # Max_OOS_sharpe_ratio: 58.9161
# # matrix: 348 # max index: 74 # Max_IS_sharpe_ratio: 65.8099 # Max_OOS_sharpe_ratio: 58.6321
# # matrix: 349 # max index: 6 # Max_IS_sharpe_ratio: 65.1136 # Max_OOS_sharpe_ratio: 59.2296
# # matrix: 350 # max index: 89 # Max_IS_sharpe_ratio: 66.192 # Max_OOS_sharpe_ratio: 58.4136
# # matrix: 351 # max index: 34 # Max_IS_sharpe_ratio: 65.2215 # Max_OOS_sharpe_ratio: 59.0731
# # matrix: 352 # max index: 90 # Max_IS_sharpe_ratio: 64.7516 # Max_OOS_sharpe_ratio: 59.4209
# # matrix: 353 # max index: 59 # Max_IS_sharpe_ratio: 66.3232 # Max_OOS_sharpe_ratio: 58.3577
# # matrix: 354 # max index: 59 # Max_IS_sharpe_ratio: 67.9477 # Max_OOS_sharpe_ratio: 57.2422
# # matrix: 355 # max index: 54 # Max_IS_sharpe_ratio: 65.1544 # Max_OOS_sharpe_ratio: 59.1805
# # matrix: 356 # max index: 76 # Max_IS_sharpe_ratio: 65.8516 # Max_OOS_sharpe_ratio: 58.8021
# # matrix: 357 # max index: 10 # Max_IS_sharpe_ratio: 65.7774 # Max_OOS_sharpe_ratio: 58.6595
# # matrix: 358 # max index: 40 # Max_IS_sharpe_ratio: 65.5332 # Max_OOS_sharpe_ratio: 58.8318
# # matrix: 359 # max index: 16 # Max_IS_sharpe_ratio: 66.0226 # Max_OOS_sharpe_ratio: 58.483
# # matrix: 360 # max index: 40 # Max_IS_sharpe_ratio: 66.9264 # Max_OOS_sharpe_ratio: 57.9105
# # matrix: 361 # max index: 36 # Max_IS_sharpe_ratio: 65.7326 # Max_OOS_sharpe_ratio: 58.9028
# # matrix: 362 # max index: 92 # Max_IS_sharpe_ratio: 66.2934 # Max_OOS_sharpe_ratio: 58.2988
# # matrix: 363 # max index: 48 # Max_IS_sharpe_ratio: 65.6993 # Max_OOS_sharpe_ratio: 58.7162
# # matrix: 364 # max index: 85 # Max_IS_sharpe_ratio: 65.6398 # Max_OOS_sharpe_ratio: 58.7532
# # matrix: 365 # max index: 37 # Max_IS_sharpe_ratio: 66.7929 # Max_OOS_sharpe_ratio: 58.0771
# # matrix: 366 # max index: 94 # Max_IS_sharpe_ratio: 66.6125 # Max_OOS_sharpe_ratio: 58.0841
# # matrix: 367 # max index: 82 # Max_IS_sharpe_ratio: 65.5909 # Max_OOS_sharpe_ratio: 58.8073
# # matrix: 368 # max index: 70 # Max_IS_sharpe_ratio: 65.7184 # Max_OOS_sharpe_ratio: 58.7833
# # matrix: 369 # max index: 48 # Max_IS_sharpe_ratio: 65.6824 # Max_OOS_sharpe_ratio: 58.7375
# # matrix: 370 # max index: 92 # Max_IS_sharpe_ratio: 65.6039 # Max_OOS_sharpe_ratio: 58.8197
# # matrix: 371 # max index: 42 # Max_IS_sharpe_ratio: 66.0573 # Max_OOS_sharpe_ratio: 58.4681
# # matrix: 372 # max index: 8 # Max_IS_sharpe_ratio: 64.3384 # Max_OOS_sharpe_ratio: 59.8495
# # matrix: 373 # max index: 84 # Max_IS_sharpe_ratio: 66.245 # Max_OOS_sharpe_ratio: 58.4527
# # matrix: 374 # max index: 98 # Max_IS_sharpe_ratio: 65.9462 # Max_OOS_sharpe_ratio: 58.5774
# # matrix: 375 # max index: 70 # Max_IS_sharpe_ratio: 65.1512 # Max_OOS_sharpe_ratio: 59.1239
# # matrix: 376 # max index: 0 # Max_IS_sharpe_ratio: 67.3911 # Max_OOS_sharpe_ratio: 57.612
# # matrix: 377 # max index: 35 # Max_IS_sharpe_ratio: 65.0339 # Max_OOS_sharpe_ratio: 59.3422
# # matrix: 378 # max index: 2 # Max_IS_sharpe_ratio: 66.0822 # Max_OOS_sharpe_ratio: 58.4448
# # matrix: 379 # max index: 76 # Max_IS_sharpe_ratio: 65.7273 # Max_OOS_sharpe_ratio: 58.7063
# # matrix: 380 # max index: 38 # Max_IS_sharpe_ratio: 66.8614 # Max_OOS_sharpe_ratio: 57.9311
# # matrix: 381 # max index: 77 # Max_IS_sharpe_ratio: 65.7252 # Max_OOS_sharpe_ratio: 58.7015
# # matrix: 382 # max index: 9 # Max_IS_sharpe_ratio: 65.2022 # Max_OOS_sharpe_ratio: 59.0762
# # matrix: 383 # max index: 21 # Max_IS_sharpe_ratio: 64.9271 # Max_OOS_sharpe_ratio: 59.3305
# # matrix: 384 # max index: 23 # Max_IS_sharpe_ratio: 65.6152 # Max_OOS_sharpe_ratio: 58.7776
# # matrix: 385 # max index: 10 # Max_IS_sharpe_ratio: 66.2303 # Max_OOS_sharpe_ratio: 58.3412
# # matrix: 386 # max index: 73 # Max_IS_sharpe_ratio: 66.1071 # Max_OOS_sharpe_ratio: 58.4823
# # matrix: 387 # max index: 15 # Max_IS_sharpe_ratio: 66.629 # Max_OOS_sharpe_ratio: 58.1774
# # matrix: 388 # max index: 30 # Max_IS_sharpe_ratio: 65.3822 # Max_OOS_sharpe_ratio: 58.94
# # matrix: 389 # max index: 19 # Max_IS_sharpe_ratio: 66.0972 # Max_OOS_sharpe_ratio: 58.4503
# # matrix: 390 # max index: 26 # Max_IS_sharpe_ratio: 65.7211 # Max_OOS_sharpe_ratio: 58.6972
# # matrix: 391 # max index: 28 # Max_IS_sharpe_ratio: 66.5802 # Max_OOS_sharpe_ratio: 58.1292
# # matrix: 392 # max index: 90 # Max_IS_sharpe_ratio: 64.7012 # Max_OOS_sharpe_ratio: 59.455
# # matrix: 393 # max index: 15 # Max_IS_sharpe_ratio: 64.3578 # Max_OOS_sharpe_ratio: 59.7987
# # matrix: 394 # max index: 89 # Max_IS_sharpe_ratio: 67.9244 # Max_OOS_sharpe_ratio: 57.2881
# # matrix: 395 # max index: 63 # Max_IS_sharpe_ratio: 66.2453 # Max_OOS_sharpe_ratio: 58.3388
# # matrix: 396 # max index: 40 # Max_IS_sharpe_ratio: 66.102 # Max_OOS_sharpe_ratio: 58.4325
# # matrix: 397 # max index: 33 # Max_IS_sharpe_ratio: 66.0469 # Max_OOS_sharpe_ratio: 58.4682
# # matrix: 398 # max index: 39 # Max_IS_sharpe_ratio: 66.6335 # Max_OOS_sharpe_ratio: 58.122
# # matrix: 399 # max index: 39 # Max_IS_sharpe_ratio: 64.551 # Max_OOS_sharpe_ratio: 59.584
# # matrix: 400 # max index: 26 # Max_IS_sharpe_ratio: 65.7661 # Max_OOS_sharpe_ratio: 58.8639
# # matrix: 401 # max index: 16 # Max_IS_sharpe_ratio: 65.2536 # Max_OOS_sharpe_ratio: 59.0641
# # matrix: 402 # max index: 17 # Max_IS_sharpe_ratio: 66.7914 # Max_OOS_sharpe_ratio: 57.9694
# # matrix: 403 # max index: 8 # Max_IS_sharpe_ratio: 67.0064 # Max_OOS_sharpe_ratio: 57.8343
# # matrix: 404 # max index: 96 # Max_IS_sharpe_ratio: 65.9605 # Max_OOS_sharpe_ratio: 58.5267
# # matrix: 405 # max index: 67 # Max_IS_sharpe_ratio: 65.9028 # Max_OOS_sharpe_ratio: 58.5851
# # matrix: 406 # max index: 10 # Max_IS_sharpe_ratio: 65.5282 # Max_OOS_sharpe_ratio: 58.8375
# # matrix: 407 # max index: 63 # Max_IS_sharpe_ratio: 65.2537 # Max_OOS_sharpe_ratio: 59.0684
# # matrix: 408 # max index: 7 # Max_IS_sharpe_ratio: 65.137 # Max_OOS_sharpe_ratio: 59.1544
# # matrix: 409 # max index: 9 # Max_IS_sharpe_ratio: 65.5324 # Max_OOS_sharpe_ratio: 58.9118
# # matrix: 410 # max index: 27 # Max_IS_sharpe_ratio: 66.586 # Max_OOS_sharpe_ratio: 58.1021
# # matrix: 411 # max index: 68 # Max_IS_sharpe_ratio: 65.8864 # Max_OOS_sharpe_ratio: 58.5811
# # matrix: 412 # max index: 42 # Max_IS_sharpe_ratio: 67.657 # Max_OOS_sharpe_ratio: 57.4348
# # matrix: 413 # max index: 33 # Max_IS_sharpe_ratio: 65.8747 # Max_OOS_sharpe_ratio: 58.6346
# # matrix: 414 # max index: 37 # Max_IS_sharpe_ratio: 65.5882 # Max_OOS_sharpe_ratio: 58.7912
# # matrix: 415 # max index: 24 # Max_IS_sharpe_ratio: 65.6032 # Max_OOS_sharpe_ratio: 58.807
# # matrix: 416 # max index: 72 # Max_IS_sharpe_ratio: 66.6199 # Max_OOS_sharpe_ratio: 58.0889
# # matrix: 417 # max index: 30 # Max_IS_sharpe_ratio: 65.6769 # Max_OOS_sharpe_ratio: 58.7674
# # matrix: 418 # max index: 83 # Max_IS_sharpe_ratio: 65.8447 # Max_OOS_sharpe_ratio: 58.9117
# # matrix: 419 # max index: 75 # Max_IS_sharpe_ratio: 65.132 # Max_OOS_sharpe_ratio: 59.1484
# # matrix: 420 # max index: 51 # Max_IS_sharpe_ratio: 65.1673 # Max_OOS_sharpe_ratio: 59.165
# # matrix: 421 # max index: 70 # Max_IS_sharpe_ratio: 67.3336 # Max_OOS_sharpe_ratio: 57.6305
# # matrix: 422 # max index: 18 # Max_IS_sharpe_ratio: 65.1311 # Max_OOS_sharpe_ratio: 59.1751
# # matrix: 423 # max index: 64 # Max_IS_sharpe_ratio: 65.6873 # Max_OOS_sharpe_ratio: 58.7436
# # matrix: 424 # max index: 16 # Max_IS_sharpe_ratio: 65.128 # Max_OOS_sharpe_ratio: 59.1319
# # matrix: 425 # max index: 89 # Max_IS_sharpe_ratio: 64.7469 # Max_OOS_sharpe_ratio: 59.4216
# # matrix: 426 # max index: 94 # Max_IS_sharpe_ratio: 65.3725 # Max_OOS_sharpe_ratio: 59.0406
# # matrix: 427 # max index: 92 # Max_IS_sharpe_ratio: 64.8142 # Max_OOS_sharpe_ratio: 59.3707
# # matrix: 428 # max index: 7 # Max_IS_sharpe_ratio: 64.847 # Max_OOS_sharpe_ratio: 59.4084
# # matrix: 429 # max index: 35 # Max_IS_sharpe_ratio: 66.8927 # Max_OOS_sharpe_ratio: 57.9023
# # matrix: 430 # max index: 36 # Max_IS_sharpe_ratio: 65.5985 # Max_OOS_sharpe_ratio: 58.7829
# # matrix: 431 # max index: 54 # Max_IS_sharpe_ratio: 65.8376 # Max_OOS_sharpe_ratio: 58.6521
# # matrix: 432 # max index: 57 # Max_IS_sharpe_ratio: 65.7496 # Max_OOS_sharpe_ratio: 58.8529
# # matrix: 433 # max index: 83 # Max_IS_sharpe_ratio: 66.8897 # Max_OOS_sharpe_ratio: 57.9017
# # matrix: 434 # max index: 79 # Max_IS_sharpe_ratio: 65.1829 # Max_OOS_sharpe_ratio: 59.384
# # matrix: 435 # max index: 91 # Max_IS_sharpe_ratio: 66.9292 # Max_OOS_sharpe_ratio: 57.9967
# # matrix: 436 # max index: 69 # Max_IS_sharpe_ratio: 65.8732 # Max_OOS_sharpe_ratio: 58.8121
# # matrix: 437 # max index: 76 # Max_IS_sharpe_ratio: 65.9293 # Max_OOS_sharpe_ratio: 58.6953
# # matrix: 438 # max index: 10 # Max_IS_sharpe_ratio: 65.6488 # Max_OOS_sharpe_ratio: 58.7989
# # matrix: 439 # max index: 51 # Max_IS_sharpe_ratio: 65.246 # Max_OOS_sharpe_ratio: 59.2121
# # matrix: 440 # max index: 28 # Max_IS_sharpe_ratio: 65.6668 # Max_OOS_sharpe_ratio: 58.7364
# # matrix: 441 # max index: 12 # Max_IS_sharpe_ratio: 64.7259 # Max_OOS_sharpe_ratio: 59.4358
# # matrix: 442 # max index: 1 # Max_IS_sharpe_ratio: 66.0802 # Max_OOS_sharpe_ratio: 58.5429
# # matrix: 443 # max index: 72 # Max_IS_sharpe_ratio: 66.2449 # Max_OOS_sharpe_ratio: 58.3318
# # matrix: 444 # max index: 48 # Max_IS_sharpe_ratio: 66.8404 # Max_OOS_sharpe_ratio: 57.9435
# # matrix: 445 # max index: 58 # Max_IS_sharpe_ratio: 66.746 # Max_OOS_sharpe_ratio: 57.9944
# # matrix: 446 # max index: 47 # Max_IS_sharpe_ratio: 66.0456 # Max_OOS_sharpe_ratio: 58.5162
# # matrix: 447 # max index: 34 # Max_IS_sharpe_ratio: 66.3666 # Max_OOS_sharpe_ratio: 58.2517
# # matrix: 448 # max index: 68 # Max_IS_sharpe_ratio: 65.0732 # Max_OOS_sharpe_ratio: 59.1693
# # matrix: 449 # max index: 0 # Max_IS_sharpe_ratio: 65.0347 # Max_OOS_sharpe_ratio: 59.2037
# # matrix: 450 # max index: 26 # Max_IS_sharpe_ratio: 65.419 # Max_OOS_sharpe_ratio: 58.9484
# # matrix: 451 # max index: 93 # Max_IS_sharpe_ratio: 64.9222 # Max_OOS_sharpe_ratio: 59.5147
# # matrix: 452 # max index: 48 # Max_IS_sharpe_ratio: 64.8205 # Max_OOS_sharpe_ratio: 59.3616
# # matrix: 453 # max index: 19 # Max_IS_sharpe_ratio: 65.3118 # Max_OOS_sharpe_ratio: 59.0037
# # matrix: 454 # max index: 43 # Max_IS_sharpe_ratio: 65.1637 # Max_OOS_sharpe_ratio: 59.1367
# # matrix: 455 # max index: 66 # Max_IS_sharpe_ratio: 64.6936 # Max_OOS_sharpe_ratio: 59.5151
# # matrix: 456 # max index: 15 # Max_IS_sharpe_ratio: 65.5399 # Max_OOS_sharpe_ratio: 58.9003
# # matrix: 457 # max index: 8 # Max_IS_sharpe_ratio: 65.7851 # Max_OOS_sharpe_ratio: 58.6635
# # matrix: 458 # max index: 16 # Max_IS_sharpe_ratio: 64.9392 # Max_OOS_sharpe_ratio: 59.3518
# # matrix: 459 # max index: 83 # Max_IS_sharpe_ratio: 66.2324 # Max_OOS_sharpe_ratio: 58.3432
# # matrix: 460 # max index: 65 # Max_IS_sharpe_ratio: 65.8265 # Max_OOS_sharpe_ratio: 58.7493
# # matrix: 461 # max index: 57 # Max_IS_sharpe_ratio: 66.0711 # Max_OOS_sharpe_ratio: 58.4516
# # matrix: 462 # max index: 38 # Max_IS_sharpe_ratio: 66.1593 # Max_OOS_sharpe_ratio: 58.4142
# # matrix: 463 # max index: 58 # Max_IS_sharpe_ratio: 65.3741 # Max_OOS_sharpe_ratio: 59.033
# # matrix: 464 # max index: 26 # Max_IS_sharpe_ratio: 65.9922 # Max_OOS_sharpe_ratio: 58.5071
# # matrix: 465 # max index: 15 # Max_IS_sharpe_ratio: 66.5381 # Max_OOS_sharpe_ratio: 58.1564
# # matrix: 466 # max index: 7 # Max_IS_sharpe_ratio: 65.9888 # Max_OOS_sharpe_ratio: 58.5151
# # matrix: 467 # max index: 21 # Max_IS_sharpe_ratio: 66.2757 # Max_OOS_sharpe_ratio: 58.3111
# # matrix: 468 # max index: 53 # Max_IS_sharpe_ratio: 65.4636 # Max_OOS_sharpe_ratio: 58.9475
# # matrix: 469 # max index: 92 # Max_IS_sharpe_ratio: 65.5917 # Max_OOS_sharpe_ratio: 58.8136
# # matrix: 470 # max index: 35 # Max_IS_sharpe_ratio: 66.3599 # Max_OOS_sharpe_ratio: 58.2605
# # matrix: 471 # max index: 60 # Max_IS_sharpe_ratio: 65.6137 # Max_OOS_sharpe_ratio: 58.8051
# # matrix: 472 # max index: 1 # Max_IS_sharpe_ratio: 65.5564 # Max_OOS_sharpe_ratio: 58.8181
# # matrix: 473 # max index: 83 # Max_IS_sharpe_ratio: 66.3765 # Max_OOS_sharpe_ratio: 58.2664
# # matrix: 474 # max index: 75 # Max_IS_sharpe_ratio: 65.1844 # Max_OOS_sharpe_ratio: 59.1052
# # matrix: 475 # max index: 35 # Max_IS_sharpe_ratio: 65.1887 # Max_OOS_sharpe_ratio: 59.1733
# # matrix: 476 # max index: 72 # Max_IS_sharpe_ratio: 65.2383 # Max_OOS_sharpe_ratio: 59.201
# # matrix: 477 # max index: 50 # Max_IS_sharpe_ratio: 65.8924 # Max_OOS_sharpe_ratio: 58.6072
# # matrix: 478 # max index: 11 # Max_IS_sharpe_ratio: 65.7269 # Max_OOS_sharpe_ratio: 58.7504
# # matrix: 479 # max index: 23 # Max_IS_sharpe_ratio: 66.1297 # Max_OOS_sharpe_ratio: 58.465
# # matrix: 480 # max index: 47 # Max_IS_sharpe_ratio: 66.8222 # Max_OOS_sharpe_ratio: 57.9681
# # matrix: 481 # max index: 43 # Max_IS_sharpe_ratio: 64.8076 # Max_OOS_sharpe_ratio: 59.3741
# # matrix: 482 # max index: 87 # Max_IS_sharpe_ratio: 65.2333 # Max_OOS_sharpe_ratio: 59.0497
# # matrix: 483 # max index: 39 # Max_IS_sharpe_ratio: 65.6178 # Max_OOS_sharpe_ratio: 58.7703
# # matrix: 484 # max index: 94 # Max_IS_sharpe_ratio: 67.2779 # Max_OOS_sharpe_ratio: 57.7164
# # matrix: 485 # max index: 60 # Max_IS_sharpe_ratio: 66.6246 # Max_OOS_sharpe_ratio: 58.1877
# # matrix: 486 # max index: 63 # Max_IS_sharpe_ratio: 65.7451 # Max_OOS_sharpe_ratio: 58.7017
# # matrix: 487 # max index: 27 # Max_IS_sharpe_ratio: 65.5671 # Max_OOS_sharpe_ratio: 58.8757
# # matrix: 488 # max index: 48 # Max_IS_sharpe_ratio: 66.618 # Max_OOS_sharpe_ratio: 58.1189
# # matrix: 489 # max index: 52 # Max_IS_sharpe_ratio: 66.0078 # Max_OOS_sharpe_ratio: 58.4954
# # matrix: 490 # max index: 41 # Max_IS_sharpe_ratio: 64.819 # Max_OOS_sharpe_ratio: 59.5318
# # matrix: 491 # max index: 98 # Max_IS_sharpe_ratio: 65.6948 # Max_OOS_sharpe_ratio: 58.718
# # matrix: 492 # max index: 69 # Max_IS_sharpe_ratio: 65.5067 # Max_OOS_sharpe_ratio: 58.8518
# # matrix: 493 # max index: 85 # Max_IS_sharpe_ratio: 65.0082 # Max_OOS_sharpe_ratio: 59.2185
# # matrix: 494 # max index: 11 # Max_IS_sharpe_ratio: 64.9877 # Max_OOS_sharpe_ratio: 59.2425
# # matrix: 495 # max index: 43 # Max_IS_sharpe_ratio: 66.5404 # Max_OOS_sharpe_ratio: 58.1365
# # matrix: 496 # max index: 29 # Max_IS_sharpe_ratio: 65.9137 # Max_OOS_sharpe_ratio: 58.5877
# # matrix: 497 # max index: 33 # Max_IS_sharpe_ratio: 65.9531 # Max_OOS_sharpe_ratio: 58.5984
# # matrix: 498 # max index: 8 # Max_IS_sharpe_ratio: 65.2859 # Max_OOS_sharpe_ratio: 59.0352
# # matrix: 499 # max index: 28 # Max_IS_sharpe_ratio: 65.9934 # Max_OOS_sharpe_ratio: 58.518
# # matrix: 500 # max index: 68 # Max_IS_sharpe_ratio: 64.8666 # Max_OOS_sharpe_ratio: 59.3334
# # matrix: 501 # max index: 26 # Max_IS_sharpe_ratio: 65.4315 # Max_OOS_sharpe_ratio: 59.0135
# # matrix: 502 # max index: 41 # Max_IS_sharpe_ratio: 65.8097 # Max_OOS_sharpe_ratio: 58.7436
# # matrix: 503 # max index: 4 # Max_IS_sharpe_ratio: 65.0578 # Max_OOS_sharpe_ratio: 59.1816
# # matrix: 504 # max index: 18 # Max_IS_sharpe_ratio: 66.4165 # Max_OOS_sharpe_ratio: 58.3036
# # matrix: 505 # max index: 56 # Max_IS_sharpe_ratio: 65.8856 # Max_OOS_sharpe_ratio: 58.9129
# # matrix: 506 # max index: 96 # Max_IS_sharpe_ratio: 65.5567 # Max_OOS_sharpe_ratio: 58.8153
# # matrix: 507 # max index: 82 # Max_IS_sharpe_ratio: 66.1435 # Max_OOS_sharpe_ratio: 58.4001
# # matrix: 508 # max index: 62 # Max_IS_sharpe_ratio: 65.3522 # Max_OOS_sharpe_ratio: 58.9799
# # matrix: 509 # max index: 96 # Max_IS_sharpe_ratio: 65.4133 # Max_OOS_sharpe_ratio: 58.9286
# # matrix: 510 # max index: 89 # Max_IS_sharpe_ratio: 65.8476 # Max_OOS_sharpe_ratio: 58.7892
# # matrix: 511 # max index: 22 # Max_IS_sharpe_ratio: 66.2642 # Max_OOS_sharpe_ratio: 58.3846
# # matrix: 512 # max index: 80 # Max_IS_sharpe_ratio: 65.7783 # Max_OOS_sharpe_ratio: 58.6849
# # matrix: 513 # max index: 79 # Max_IS_sharpe_ratio: 65.4208 # Max_OOS_sharpe_ratio: 58.9488
# # matrix: 514 # max index: 45 # Max_IS_sharpe_ratio: 65.402 # Max_OOS_sharpe_ratio: 58.9402
# # matrix: 515 # max index: 67 # Max_IS_sharpe_ratio: 64.8367 # Max_OOS_sharpe_ratio: 59.3522
# # matrix: 516 # max index: 65 # Max_IS_sharpe_ratio: 65.5255 # Max_OOS_sharpe_ratio: 59.0724
# # matrix: 517 # max index: 92 # Max_IS_sharpe_ratio: 65.7026 # Max_OOS_sharpe_ratio: 58.769
# # matrix: 518 # max index: 26 # Max_IS_sharpe_ratio: 66.4436 # Max_OOS_sharpe_ratio: 58.2055
# ...
# # matrix: 828 # max index: 3 # Max_IS_sharpe_ratio: 64.586 # Max_OOS_sharpe_ratio: 59.6046
# # matrix: 829 # max index: 11 # Max_IS_sharpe_ratio: 65.8042 # Max_OOS_sharpe_ratio: 58.6529
# # matrix: 830 # max index: 19 # Max_IS_sharpe_ratio: 66.4221 # Max_OOS_sharpe_ratio: 58.2208
# # matrix: 831 # max index: 56 # Max_IS_sharpe_ratio: 65.459 # Max_OOS_sharpe_ratio: 59.0314
# # matrix: 832 # max index: 48 # Max_IS_sharpe_ratio: 65.1131 # Max_OOS_sharpe_ratio: 59.1801
# # matrix: 833 # max index: 4 # Max_IS_sharpe_ratio: 64.626 # Max_OOS_sharpe_ratio: 59.5405
# # matrix: 834 # max index: 18 # Max_IS_sharpe_ratio: 65.7029 # Max_OOS_sharpe_ratio: 58.7595
# # matrix: 835 # max index: 11 # Max_IS_sharpe_ratio: 66.1289 # Max_OOS_sharpe_ratio: 58.535
# # matrix: 836 # max index: 95 # Max_IS_sharpe_ratio: 65.8434 # Max_OOS_sharpe_ratio: 58.7922
# # matrix: 837 # max index: 52 # Max_IS_sharpe_ratio: 65.7873 # Max_OOS_sharpe_ratio: 58.7519
# # matrix: 838 # max index: 4 # Max_IS_sharpe_ratio: 66.3311 # Max_OOS_sharpe_ratio: 58.3063
# # matrix: 839 # max index: 84 # Max_IS_sharpe_ratio: 65.3775 # Max_OOS_sharpe_ratio: 58.9711
# # matrix: 840 # max index: 13 # Max_IS_sharpe_ratio: 65.3612 # Max_OOS_sharpe_ratio: 58.9659
# # matrix: 841 # max index: 55 # Max_IS_sharpe_ratio: 65.1584 # Max_OOS_sharpe_ratio: 59.107
# # matrix: 842 # max index: 77 # Max_IS_sharpe_ratio: 65.9435 # Max_OOS_sharpe_ratio: 58.604
# # matrix: 843 # max index: 17 # Max_IS_sharpe_ratio: 65.4315 # Max_OOS_sharpe_ratio: 59.0645
# # matrix: 844 # max index: 28 # Max_IS_sharpe_ratio: 65.5101 # Max_OOS_sharpe_ratio: 58.8467
# # matrix: 845 # max index: 87 # Max_IS_sharpe_ratio: 65.1409 # Max_OOS_sharpe_ratio: 59.1301
# # matrix: 846 # max index: 76 # Max_IS_sharpe_ratio: 66.0466 # Max_OOS_sharpe_ratio: 58.668
# # matrix: 847 # max index: 40 # Max_IS_sharpe_ratio: 66.7706 # Max_OOS_sharpe_ratio: 57.9883
# # matrix: 848 # max index: 54 # Max_IS_sharpe_ratio: 65.7234 # Max_OOS_sharpe_ratio: 58.7662
# # matrix: 849 # max index: 22 # Max_IS_sharpe_ratio: 66.0641 # Max_OOS_sharpe_ratio: 58.4642
# # matrix: 850 # max index: 25 # Max_IS_sharpe_ratio: 65.9597 # Max_OOS_sharpe_ratio: 58.5314
# # matrix: 851 # max index: 4 # Max_IS_sharpe_ratio: 65.6143 # Max_OOS_sharpe_ratio: 58.7746
# # matrix: 852 # max index: 33 # Max_IS_sharpe_ratio: 65.8888 # Max_OOS_sharpe_ratio: 58.5765
# # matrix: 853 # max index: 5 # Max_IS_sharpe_ratio: 65.308 # Max_OOS_sharpe_ratio: 59.0055
# # matrix: 854 # max index: 96 # Max_IS_sharpe_ratio: 67.5814 # Max_OOS_sharpe_ratio: 57.4657
# # matrix: 855 # max index: 44 # Max_IS_sharpe_ratio: 65.5872 # Max_OOS_sharpe_ratio: 58.7986
# # matrix: 856 # max index: 39 # Max_IS_sharpe_ratio: 66.6048 # Max_OOS_sharpe_ratio: 58.1862
# # matrix: 857 # max index: 67 # Max_IS_sharpe_ratio: 66.6489 # Max_OOS_sharpe_ratio: 58.0886
# # matrix: 858 # max index: 59 # Max_IS_sharpe_ratio: 66.5899 # Max_OOS_sharpe_ratio: 58.3468
# # matrix: 859 # max index: 21 # Max_IS_sharpe_ratio: 65.4808 # Max_OOS_sharpe_ratio: 58.8795
# # matrix: 860 # max index: 96 # Max_IS_sharpe_ratio: 65.1701 # Max_OOS_sharpe_ratio: 59.1435
# # matrix: 861 # max index: 23 # Max_IS_sharpe_ratio: 65.307 # Max_OOS_sharpe_ratio: 59.0652
# # matrix: 862 # max index: 71 # Max_IS_sharpe_ratio: 65.3417 # Max_OOS_sharpe_ratio: 59.1618
# # matrix: 863 # max index: 17 # Max_IS_sharpe_ratio: 66.6361 # Max_OOS_sharpe_ratio: 58.127
# # matrix: 864 # max index: 17 # Max_IS_sharpe_ratio: 65.1973 # Max_OOS_sharpe_ratio: 59.0804
# # matrix: 865 # max index: 76 # Max_IS_sharpe_ratio: 65.3182 # Max_OOS_sharpe_ratio: 59.0184
# # matrix: 866 # max index: 69 # Max_IS_sharpe_ratio: 67.4237 # Max_OOS_sharpe_ratio: 58.1323
# # matrix: 867 # max index: 95 # Max_IS_sharpe_ratio: 65.7264 # Max_OOS_sharpe_ratio: 58.7597
# # matrix: 868 # max index: 84 # Max_IS_sharpe_ratio: 65.0274 # Max_OOS_sharpe_ratio: 59.204
# # matrix: 869 # max index: 32 # Max_IS_sharpe_ratio: 65.6347 # Max_OOS_sharpe_ratio: 58.7847
# # matrix: 870 # max index: 66 # Max_IS_sharpe_ratio: 66.0724 # Max_OOS_sharpe_ratio: 58.4545
# # matrix: 871 # max index: 98 # Max_IS_sharpe_ratio: 64.9721 # Max_OOS_sharpe_ratio: 59.3292
# # matrix: 872 # max index: 18 # Max_IS_sharpe_ratio: 66.3997 # Max_OOS_sharpe_ratio: 58.2266
# # matrix: 873 # max index: 83 # Max_IS_sharpe_ratio: 65.6546 # Max_OOS_sharpe_ratio: 58.7436
# # matrix: 874 # max index: 8 # Max_IS_sharpe_ratio: 66.2353 # Max_OOS_sharpe_ratio: 58.4474
# # matrix: 875 # max index: 19 # Max_IS_sharpe_ratio: 65.7802 # Max_OOS_sharpe_ratio: 58.6975
# # matrix: 876 # max index: 57 # Max_IS_sharpe_ratio: 65.4925 # Max_OOS_sharpe_ratio: 58.8597
# # matrix: 877 # max index: 21 # Max_IS_sharpe_ratio: 64.9915 # Max_OOS_sharpe_ratio: 59.2489
# # matrix: 878 # max index: 6 # Max_IS_sharpe_ratio: 65.7279 # Max_OOS_sharpe_ratio: 58.6907
# # matrix: 879 # max index: 82 # Max_IS_sharpe_ratio: 65.8454 # Max_OOS_sharpe_ratio: 58.6075
# # matrix: 880 # max index: 87 # Max_IS_sharpe_ratio: 65.2287 # Max_OOS_sharpe_ratio: 59.1185
# # matrix: 881 # max index: 39 # Max_IS_sharpe_ratio: 66.0689 # Max_OOS_sharpe_ratio: 58.4531
# # matrix: 882 # max index: 38 # Max_IS_sharpe_ratio: 64.8906 # Max_OOS_sharpe_ratio: 59.5966
# # matrix: 883 # max index: 49 # Max_IS_sharpe_ratio: 65.2482 # Max_OOS_sharpe_ratio: 59.0666
# # matrix: 884 # max index: 94 # Max_IS_sharpe_ratio: 64.3798 # Max_OOS_sharpe_ratio: 59.7941
# # matrix: 885 # max index: 62 # Max_IS_sharpe_ratio: 65.5578 # Max_OOS_sharpe_ratio: 58.8177
# # matrix: 886 # max index: 48 # Max_IS_sharpe_ratio: 66.9838 # Max_OOS_sharpe_ratio: 57.8439
# # matrix: 887 # max index: 33 # Max_IS_sharpe_ratio: 65.4673 # Max_OOS_sharpe_ratio: 58.8792
# # matrix: 888 # max index: 67 # Max_IS_sharpe_ratio: 65.4491 # Max_OOS_sharpe_ratio: 58.9812
# # matrix: 889 # max index: 68 # Max_IS_sharpe_ratio: 65.0546 # Max_OOS_sharpe_ratio: 59.184
# # matrix: 890 # max index: 52 # Max_IS_sharpe_ratio: 66.3057 # Max_OOS_sharpe_ratio: 58.2915
# # matrix: 891 # max index: 70 # Max_IS_sharpe_ratio: 66.1686 # Max_OOS_sharpe_ratio: 58.3836
# # matrix: 892 # max index: 29 # Max_IS_sharpe_ratio: 64.5409 # Max_OOS_sharpe_ratio: 59.5825
# # matrix: 893 # max index: 66 # Max_IS_sharpe_ratio: 66.1997 # Max_OOS_sharpe_ratio: 58.3835
# # matrix: 894 # max index: 91 # Max_IS_sharpe_ratio: 66.0576 # Max_OOS_sharpe_ratio: 58.4707
# # matrix: 895 # max index: 27 # Max_IS_sharpe_ratio: 65.7628 # Max_OOS_sharpe_ratio: 58.7538
# # matrix: 896 # max index: 86 # Max_IS_sharpe_ratio: 66.3764 # Max_OOS_sharpe_ratio: 58.2405
# # matrix: 897 # max index: 42 # Max_IS_sharpe_ratio: 65.5274 # Max_OOS_sharpe_ratio: 58.888
# # matrix: 898 # max index: 22 # Max_IS_sharpe_ratio: 66.0206 # Max_OOS_sharpe_ratio: 58.4845
# # matrix: 899 # max index: 23 # Max_IS_sharpe_ratio: 66.2788 # Max_OOS_sharpe_ratio: 58.3083
# # matrix: 900 # max index: 3 # Max_IS_sharpe_ratio: 65.3477 # Max_OOS_sharpe_ratio: 58.9653
# # matrix: 901 # max index: 49 # Max_IS_sharpe_ratio: 66.3905 # Max_OOS_sharpe_ratio: 58.2374
# # matrix: 902 # max index: 50 # Max_IS_sharpe_ratio: 66.7339 # Max_OOS_sharpe_ratio: 58.2391
# # matrix: 903 # max index: 11 # Max_IS_sharpe_ratio: 64.7444 # Max_OOS_sharpe_ratio: 59.4654
# # matrix: 904 # max index: 56 # Max_IS_sharpe_ratio: 65.0032 # Max_OOS_sharpe_ratio: 59.2284
# # matrix: 905 # max index: 79 # Max_IS_sharpe_ratio: 64.6526 # Max_OOS_sharpe_ratio: 59.4914
# # matrix: 906 # max index: 17 # Max_IS_sharpe_ratio: 66.4572 # Max_OOS_sharpe_ratio: 58.1987
# # matrix: 907 # max index: 51 # Max_IS_sharpe_ratio: 64.7807 # Max_OOS_sharpe_ratio: 59.4063
# # matrix: 908 # max index: 77 # Max_IS_sharpe_ratio: 64.5707 # Max_OOS_sharpe_ratio: 59.711
# # matrix: 909 # max index: 39 # Max_IS_sharpe_ratio: 65.171 # Max_OOS_sharpe_ratio: 59.2027
# # matrix: 910 # max index: 37 # Max_IS_sharpe_ratio: 66.0334 # Max_OOS_sharpe_ratio: 58.5531
# # matrix: 911 # max index: 71 # Max_IS_sharpe_ratio: 64.8077 # Max_OOS_sharpe_ratio: 59.3716
# # matrix: 912 # max index: 58 # Max_IS_sharpe_ratio: 65.9828 # Max_OOS_sharpe_ratio: 58.5108
# # matrix: 913 # max index: 17 # Max_IS_sharpe_ratio: 66.6415 # Max_OOS_sharpe_ratio: 58.2799
# # matrix: 914 # max index: 94 # Max_IS_sharpe_ratio: 67.0051 # Max_OOS_sharpe_ratio: 57.8477
# # matrix: 915 # max index: 35 # Max_IS_sharpe_ratio: 65.6095 # Max_OOS_sharpe_ratio: 58.7754
# # matrix: 916 # max index: 8 # Max_IS_sharpe_ratio: 64.7616 # Max_OOS_sharpe_ratio: 59.4124
# # matrix: 917 # max index: 91 # Max_IS_sharpe_ratio: 65.7276 # Max_OOS_sharpe_ratio: 58.6906
# # matrix: 918 # max index: 22 # Max_IS_sharpe_ratio: 65.5976 # Max_OOS_sharpe_ratio: 59.2374
# # matrix: 919 # max index: 70 # Max_IS_sharpe_ratio: 65.4179 # Max_OOS_sharpe_ratio: 58.9147
# # matrix: 920 # max index: 78 # Max_IS_sharpe_ratio: 65.3084 # Max_OOS_sharpe_ratio: 59.0775
# # matrix: 921 # max index: 3 # Max_IS_sharpe_ratio: 66.3041 # Max_OOS_sharpe_ratio: 58.3733
# # matrix: 922 # max index: 30 # Max_IS_sharpe_ratio: 67.0952 # Max_OOS_sharpe_ratio: 57.8495
# # matrix: 923 # max index: 34 # Max_IS_sharpe_ratio: 67.3342 # Max_OOS_sharpe_ratio: 57.6176
# # matrix: 924 # max index: 20 # Max_IS_sharpe_ratio: 65.5103 # Max_OOS_sharpe_ratio: 58.8487
# # matrix: 925 # max index: 14 # Max_IS_sharpe_ratio: 65.8862 # Max_OOS_sharpe_ratio: 58.5888
# # matrix: 926 # max index: 29 # Max_IS_sharpe_ratio: 67.2657 # Max_OOS_sharpe_ratio: 57.7324
# # matrix: 927 # max index: 0 # Max_IS_sharpe_ratio: 65.5912 # Max_OOS_sharpe_ratio: 58.9185
# # matrix: 928 # max index: 59 # Max_IS_sharpe_ratio: 65.0213 # Max_OOS_sharpe_ratio: 59.2174
# # matrix: 929 # max index: 37 # Max_IS_sharpe_ratio: 65.6096 # Max_OOS_sharpe_ratio: 58.8647
# # matrix: 930 # max index: 79 # Max_IS_sharpe_ratio: 65.6118 # Max_OOS_sharpe_ratio: 58.8581
# # matrix: 931 # max index: 82 # Max_IS_sharpe_ratio: 65.4932 # Max_OOS_sharpe_ratio: 59.0303
# # matrix: 932 # max index: 10 # Max_IS_sharpe_ratio: 65.4313 # Max_OOS_sharpe_ratio: 59.0431
# # matrix: 933 # max index: 53 # Max_IS_sharpe_ratio: 67.1858 # Max_OOS_sharpe_ratio: 57.7923
# # matrix: 934 # max index: 25 # Max_IS_sharpe_ratio: 65.9141 # Max_OOS_sharpe_ratio: 58.7172
# # matrix: 935 # max index: 20 # Max_IS_sharpe_ratio: 66.0208 # Max_OOS_sharpe_ratio: 58.5665
# # matrix: 936 # max index: 65 # Max_IS_sharpe_ratio: 66.903 # Max_OOS_sharpe_ratio: 57.9803
# # matrix: 937 # max index: 88 # Max_IS_sharpe_ratio: 65.7624 # Max_OOS_sharpe_ratio: 58.6845
# # matrix: 938 # max index: 82 # Max_IS_sharpe_ratio: 66.7937 # Max_OOS_sharpe_ratio: 57.9682
# # matrix: 939 # max index: 27 # Max_IS_sharpe_ratio: 67.1911 # Max_OOS_sharpe_ratio: 57.8145
# # matrix: 940 # max index: 39 # Max_IS_sharpe_ratio: 65.9955 # Max_OOS_sharpe_ratio: 58.5048
# # matrix: 941 # max index: 98 # Max_IS_sharpe_ratio: 65.4666 # Max_OOS_sharpe_ratio: 58.9411
# # matrix: 942 # max index: 72 # Max_IS_sharpe_ratio: 65.5122 # Max_OOS_sharpe_ratio: 58.9267
# # matrix: 943 # max index: 62 # Max_IS_sharpe_ratio: 65.5633 # Max_OOS_sharpe_ratio: 58.8091
# # matrix: 944 # max index: 23 # Max_IS_sharpe_ratio: 65.2807 # Max_OOS_sharpe_ratio: 59.0355
# # matrix: 945 # max index: 52 # Max_IS_sharpe_ratio: 65.934 # Max_OOS_sharpe_ratio: 58.5473
# # matrix: 946 # max index: 47 # Max_IS_sharpe_ratio: 65.1492 # Max_OOS_sharpe_ratio: 59.1274
# # matrix: 947 # max index: 0 # Max_IS_sharpe_ratio: 66.359 # Max_OOS_sharpe_ratio: 58.2846
# # matrix: 948 # max index: 47 # Max_IS_sharpe_ratio: 66.3619 # Max_OOS_sharpe_ratio: 58.2581
# # matrix: 949 # max index: 51 # Max_IS_sharpe_ratio: 65.1191 # Max_OOS_sharpe_ratio: 59.3959
# # matrix: 950 # max index: 71 # Max_IS_sharpe_ratio: 65.7562 # Max_OOS_sharpe_ratio: 58.7211
# # matrix: 951 # max index: 64 # Max_IS_sharpe_ratio: 65.6997 # Max_OOS_sharpe_ratio: 58.7622
# # matrix: 952 # max index: 61 # Max_IS_sharpe_ratio: 65.0882 # Max_OOS_sharpe_ratio: 59.1696
# # matrix: 953 # max index: 24 # Max_IS_sharpe_ratio: 65.2496 # Max_OOS_sharpe_ratio: 59.4715
# # matrix: 954 # max index: 55 # Max_IS_sharpe_ratio: 65.254 # Max_OOS_sharpe_ratio: 59.0376
# # matrix: 955 # max index: 76 # Max_IS_sharpe_ratio: 65.1184 # Max_OOS_sharpe_ratio: 59.1602
# # matrix: 956 # max index: 80 # Max_IS_sharpe_ratio: 65.0817 # Max_OOS_sharpe_ratio: 59.3265
# # matrix: 957 # max index: 39 # Max_IS_sharpe_ratio: 65.0661 # Max_OOS_sharpe_ratio: 59.1971
# # matrix: 958 # max index: 98 # Max_IS_sharpe_ratio: 66.351 # Max_OOS_sharpe_ratio: 58.2645
# # matrix: 959 # max index: 89 # Max_IS_sharpe_ratio: 67.0024 # Max_OOS_sharpe_ratio: 57.8433
# # matrix: 960 # max index: 35 # Max_IS_sharpe_ratio: 67.6371 # Max_OOS_sharpe_ratio: 57.5104
# # matrix: 961 # max index: 16 # Max_IS_sharpe_ratio: 65.4174 # Max_OOS_sharpe_ratio: 59.1478
# # matrix: 962 # max index: 27 # Max_IS_sharpe_ratio: 66.0878 # Max_OOS_sharpe_ratio: 58.4597
# # matrix: 963 # max index: 49 # Max_IS_sharpe_ratio: 65.5394 # Max_OOS_sharpe_ratio: 59.0144
# # matrix: 964 # max index: 83 # Max_IS_sharpe_ratio: 65.9292 # Max_OOS_sharpe_ratio: 58.5572
# # matrix: 965 # max index: 54 # Max_IS_sharpe_ratio: 64.5587 # Max_OOS_sharpe_ratio: 59.6354
# # matrix: 966 # max index: 23 # Max_IS_sharpe_ratio: 66.9201 # Max_OOS_sharpe_ratio: 57.9429
# # matrix: 967 # max index: 7 # Max_IS_sharpe_ratio: 65.7094 # Max_OOS_sharpe_ratio: 58.7042
# # matrix: 968 # max index: 27 # Max_IS_sharpe_ratio: 65.1989 # Max_OOS_sharpe_ratio: 59.42
# # matrix: 969 # max index: 15 # Max_IS_sharpe_ratio: 65.601 # Max_OOS_sharpe_ratio: 58.7822
# # matrix: 970 # max index: 44 # Max_IS_sharpe_ratio: 64.5545 # Max_OOS_sharpe_ratio: 59.6759
# # matrix: 971 # max index: 67 # Max_IS_sharpe_ratio: 65.1791 # Max_OOS_sharpe_ratio: 59.2298
# # matrix: 972 # max index: 93 # Max_IS_sharpe_ratio: 65.5571 # Max_OOS_sharpe_ratio: 58.9236
# # matrix: 973 # max index: 37 # Max_IS_sharpe_ratio: 66.2898 # Max_OOS_sharpe_ratio: 58.3037
# # matrix: 974 # max index: 95 # Max_IS_sharpe_ratio: 65.5325 # Max_OOS_sharpe_ratio: 58.8468
# # matrix: 975 # max index: 30 # Max_IS_sharpe_ratio: 65.9511 # Max_OOS_sharpe_ratio: 58.7006
# # matrix: 976 # max index: 15 # Max_IS_sharpe_ratio: 65.9766 # Max_OOS_sharpe_ratio: 58.5478
# # matrix: 977 # max index: 21 # Max_IS_sharpe_ratio: 65.1341 # Max_OOS_sharpe_ratio: 59.1379
# # matrix: 978 # max index: 48 # Max_IS_sharpe_ratio: 65.338 # Max_OOS_sharpe_ratio: 58.976
# # matrix: 979 # max index: 98 # Max_IS_sharpe_ratio: 66.3088 # Max_OOS_sharpe_ratio: 58.4746
# # matrix: 980 # max index: 93 # Max_IS_sharpe_ratio: 65.6652 # Max_OOS_sharpe_ratio: 58.7767
# # matrix: 981 # max index: 41 # Max_IS_sharpe_ratio: 65.6254 # Max_OOS_sharpe_ratio: 58.857
# # matrix: 982 # max index: 39 # Max_IS_sharpe_ratio: 65.7924 # Max_OOS_sharpe_ratio: 58.6534
# # matrix: 983 # max index: 82 # Max_IS_sharpe_ratio: 67.0475 # Max_OOS_sharpe_ratio: 57.8909
# # matrix: 984 # max index: 48 # Max_IS_sharpe_ratio: 65.4064 # Max_OOS_sharpe_ratio: 58.9299
# # matrix: 985 # max index: 98 # Max_IS_sharpe_ratio: 66.274 # Max_OOS_sharpe_ratio: 58.3672
# # matrix: 986 # max index: 43 # Max_IS_sharpe_ratio: 65.8459 # Max_OOS_sharpe_ratio: 58.6207
# # matrix: 987 # max index: 40 # Max_IS_sharpe_ratio: 65.4646 # Max_OOS_sharpe_ratio: 58.9824
# # matrix: 988 # max index: 2 # Max_IS_sharpe_ratio: 68.2724 # Max_OOS_sharpe_ratio: 57.3231
# # matrix: 989 # max index: 90 # Max_IS_sharpe_ratio: 65.1388 # Max_OOS_sharpe_ratio: 59.1851
# # matrix: 990 # max index: 63 # Max_IS_sharpe_ratio: 65.8396 # Max_OOS_sharpe_ratio: 58.6125
# # matrix: 991 # max index: 9 # Max_IS_sharpe_ratio: 66.2074 # Max_OOS_sharpe_ratio: 58.3731
# # matrix: 992 # max index: 69 # Max_IS_sharpe_ratio: 65.5498 # Max_OOS_sharpe_ratio: 58.8203
# # matrix: 993 # max index: 70 # Max_IS_sharpe_ratio: 65.246 # Max_OOS_sharpe_ratio: 59.2489
# # matrix: 994 # max index: 72 # Max_IS_sharpe_ratio: 65.6412 # Max_OOS_sharpe_ratio: 58.7647
# # matrix: 995 # max index: 40 # Max_IS_sharpe_ratio: 65.3849 # Max_OOS_sharpe_ratio: 59.0755
# # matrix: 996 # max index: 11 # Max_IS_sharpe_ratio: 66.6593 # Max_OOS_sharpe_ratio: 58.0524
# # matrix: 997 # max index: 24 # Max_IS_sharpe_ratio: 65.2615 # Max_OOS_sharpe_ratio: 59.069
# # matrix: 998 # max index: 20 # Max_IS_sharpe_ratio: 66.0052 # Max_OOS_sharpe_ratio: 58.7767
# # matrix: 999 # max index: 45 # Max_IS_sharpe_ratio: 65.3279 # Max_OOS_sharpe_ratio: 58.9805
# 1.0

# %%
# 수치 적분 적용 # 

def testAccuracy_EVT(sr_base, sr_case):
    """
    Test accuracy by numerical integration
    It does the same as testAccuracy_MC, but through numerical 
    integration of the base and case distribution
    """
    
    # 1) Parameters
    parts = 1e4
    length = 1000
    freq = 365.25 * 5 / 7.
    minX = -10
    trials = 100
    emc=0.57721566490153286 # Euler-Mascheroni constant
    
    # 2) SR distributions
    dist_base = [sr_base, ((freq + 0.5 * sr_base ** 2) / length) ** 0.5]
    dist_case = [sr_case, ((freq + 0.5 * sr_case ** 2) / length) ** 0.5]
    
    # 3) Fit Gumbel (method of moments)
    maxList = []
    for x in range(int(parts)):
        max_ = max([gauss(dist_base[0], dist_base[1]) for i in range(trials)])
        maxList.append(max_)
        
    dist_base[1] = np.std(maxList) * 6 ** 0.5 / math.pi
    dist_base[0] = np.mean(maxList) - emc * dist_base[1]
    
    # 4) Integration
    prob1 = 0
    for x in np.linspace(minX * dist_case[1], 2 * dist_case[0] - sr_base, parts):
        f_x = ss.norm.pdf(x, dist_case[0], dist_case[1])
        F_y = 1 - ss.gumbel_r.cdf(x, dist_base[0], dist_base[1])
        prob1 += f_x * F_y
        
    prob1 *= (2 * dist_case[0] - sr_base - minX * dist_case[1]) / parts
    prob2 = 1 - ss.norm.cdf(2 * dist_case[0] - sr_base, dist_case[0], dist_case[1])
    print(dist_base, dist_case)
    print(prob1, prob2, prob1 + prob2)
    return

# %%
testAccuracy_EVT(1000, 900)
# Out:
# [1051.731162010095, 7.624741747139034] [900, 20.131092689100182]
# 3.435450915804261e-07 0.9999996607877335 1.000000004332825
